# %%
import json
import numpy as np
Class="Wizard"
spell_path="./5etools/5etools-src/data/spells/"
spell_source="./5etools/5etools-src/data/generated/gendata-spell-source-lookup.json"
spell_index=spell_path+"index.json"


# Open spell index
with open(spell_index, "r") as f:
    spell_index_data = json.load(f)
#open spell source class
with open(spell_source, "r") as f:
    spell_source_data = json.load(f)

spell_index_keys=list(spell_index_data.keys())

# Loop through each book in the spell index
Spell_info=[]
for book in spell_index_keys:
    if book=="XPHB" or book=="BMT" or book=="EGW":
        continue
    book_lc = book.lower()
    spell_source_book = spell_source_data[book_lc]


    book_file=spell_path+spell_index_data[book]
    with open(book_file, "r") as f:
        spell_data = json.load(f)
        spell_data=spell_data["spell"]
    

    for spell in spell_data:
        name_source=spell["name"].lower()
        print(book,name_source)
        if name_source=="mass heal":
            print("HEREHEREHERE")


        ssb = spell_source_book.get(name_source, {})
        if ssb.get('class', {}).get('PHB', {}).get(Class) is True:
            print(1)
            
        elif Class in ssb.get('classVariant', {}).get('PHB', {}):
            print(2)
            
        else:
            continue


        Spell_info.append([spell["name"],spell["level"]])

        # sort by level then by name (case-insensitive)
Spell_info.sort(key=lambda item: (item[1], item[0].lower()))

np.save("Spell_List.npy", Spell_info)
# Out:
# AAG air bubble
# 1
# AAG create spelljamming helm
# 1
# AI distort value
# 1
# AI fast friends
# 1
# AI gift of gab
# 1
# AI incite greed
# 1
# AI jim's glowing coin
# 1
# AI jim's magic missile
# 1
# AI motivational speech
# AitFR-AVT linked glyphs
# 1
# FTD ashardalon's stride
# 2
# FTD draconic transformation
# 2
# FTD fizban's platinum shield
# 2
# FTD nathair's mischief
# 2
# FTD raulothim's psychic lance
# 2
# FTD rime's binding ice
# 2
# FTD summon draconic spirit
# 2
# GGR encode thoughts
# IDRotF create magen
# 1
# IDRotF frost fingers
# 1
# LLK flock of familiars
# 1
# LLK galder's speedy courier
# 1
# LLK galder's tower
# 1
# PHB acid splash
# 1
# PHB aid
# PHB alarm
# 1
# PHB alter self
# 1
# PHB animal friendship
# PHB animal messenger
# PHB animal shapes
# PHB animate dead
# 1
# PHB animate objects
# 1
# PHB antilife shell
# PHB antimagic field
# 1
# PHB antipathy/sympathy
# 1
# PHB arcane eye
# 1
# PHB arcane gate
# 1
# PHB arcane lock
# 1
# PHB armor of agathys
# PHB arms of hadar
# PHB astral projection
# 1
# PHB augury
# 2
# PHB aura of life
# PHB aura of purity
# PHB aura of vitality
# PHB awaken
# PHB bane
# PHB banishing smite
# PHB banishment
# 1
# PHB barkskin
# PHB beacon of hope
# PHB beast sense
# PHB bestow curse
# 1
# PHB bigby's hand
# 1
# PHB blade barrier
# PHB blade ward
# 1
# PHB bless
# PHB blight
# 1
# PHB blinding smite
# PHB blindness/deafness
# 1
# PHB blink
# 1
# PHB blur
# 1
# PHB branding smite
# PHB burning hands
# 1
# PHB call lightning
# PHB calm emotions
# PHB chain lightning
# 1
# PHB charm person
# 1
# PHB chill touch
# 1
# PHB chromatic orb
# 1
# PHB circle of death
# 1
# PHB circle of power
# PHB clairvoyance
# 1
# PHB clone
# 1
# PHB cloud of daggers
# 1
# PHB cloudkill
# 1
# PHB color spray
# 1
# PHB command
# PHB commune
# PHB commune with nature
# PHB compelled duel
# PHB comprehend languages
# 1
# PHB compulsion
# PHB cone of cold
# 1
# PHB confusion
# 1
# PHB conjure animals
# PHB conjure barrage
# PHB conjure celestial
# PHB conjure elemental
# 1
# PHB conjure fey
# PHB conjure minor elementals
# 1
# PHB conjure volley
# PHB conjure woodland beings
# PHB contact other plane
# 1
# PHB contagion
# PHB contingency
# 1
# PHB continual flame
# 1
# PHB control water
# 1
# PHB control weather
# 1
# PHB cordon of arrows
# PHB counterspell
# 1
# PHB create food and water
# PHB create or destroy water
# PHB create undead
# 1
# PHB creation
# 1
# PHB crown of madness
# 1
# PHB crusader's mantle
# PHB cure wounds
# PHB dancing lights
# 1
# PHB darkness
# 1
# PHB darkvision
# 1
# PHB daylight
# PHB death ward
# PHB delayed blast fireball
# 1
# PHB demiplane
# 1
# PHB destructive wave
# PHB detect evil and good
# PHB detect magic
# 1
# PHB detect poison and disease
# PHB detect thoughts
# 1
# PHB dimension door
# 1
# PHB disguise self
# 1
# PHB disintegrate
# 1
# PHB dispel evil and good
# PHB dispel magic
# 1
# PHB dissonant whispers
# PHB divination
# 2
# PHB divine favor
# PHB divine word
# PHB dominate beast
# PHB dominate monster
# 1
# PHB dominate person
# 1
# PHB drawmij's instant summons
# 1
# PHB dream
# 1
# PHB druidcraft
# PHB earthquake
# PHB eldritch blast
# PHB elemental weapon
# PHB enhance ability
# 2
# PHB enlarge/reduce
# 1
# PHB ensnaring strike
# PHB entangle
# PHB enthrall
# PHB etherealness
# 1
# PHB evard's black tentacles
# 1
# PHB expeditious retreat
# 1
# PHB eyebite
# 1
# PHB fabricate
# 1
# PHB faerie fire
# PHB false life
# 1
# PHB fear
# 1
# PHB feather fall
# 1
# PHB feeblemind
# 1
# PHB feign death
# 1
# PHB find familiar
# 1
# PHB find steed
# PHB find the path
# PHB find traps
# PHB finger of death
# 1
# PHB fire bolt
# 1
# PHB fire shield
# 1
# PHB fire storm
# PHB fireball
# 1
# PHB flame blade
# PHB flame strike
# PHB flaming sphere
# 1
# PHB flesh to stone
# 1
# PHB fly
# 1
# PHB fog cloud
# 1
# PHB forbiddance
# PHB forcecage
# 1
# PHB foresight
# 1
# PHB freedom of movement
# PHB friends
# 1
# PHB gaseous form
# 1
# PHB gate
# 1
# PHB geas
# 1
# PHB gentle repose
# 1
# PHB giant insect
# PHB glibness
# PHB globe of invulnerability
# 1
# PHB glyph of warding
# 1
# PHB goodberry
# PHB grasping vine
# PHB grease
# 1
# PHB greater invisibility
# 1
# PHB greater restoration
# PHB guardian of faith
# PHB guards and wards
# 1
# PHB guidance
# PHB guiding bolt
# PHB gust of wind
# 1
# PHB hail of thorns
# PHB hallow
# PHB hallucinatory terrain
# 1
# PHB harm
# PHB haste
# 1
# PHB heal
# PHB healing word
# PHB heat metal
# PHB hellish rebuke
# PHB heroes' feast
# PHB heroism
# PHB hex
# PHB hold monster
# 1
# PHB hold person
# 1
# PHB holy aura
# PHB hunger of hadar
# PHB hunter's mark
# PHB hypnotic pattern
# 1
# PHB ice storm
# 1
# PHB identify
# 1
# PHB illusory script
# 1
# PHB imprisonment
# 1
# PHB incendiary cloud
# 1
# PHB inflict wounds
# PHB insect plague
# PHB invisibility
# 1
# PHB jump
# 1
# PHB knock
# 1
# PHB legend lore
# 1
# PHB leomund's secret chest
# 1
# PHB leomund's tiny hut
# 1
# PHB lesser restoration
# PHB levitate
# 1
# PHB light
# 1
# PHB lightning arrow
# PHB lightning bolt
# 1
# PHB locate animals or plants
# PHB locate creature
# 1
# PHB locate object
# 1
# PHB longstrider
# 1
# PHB mage armor
# 1
# PHB mage hand
# 1
# PHB magic circle
# 1
# PHB magic jar
# 1
# PHB magic missile
# 1
# PHB magic mouth
# 1
# PHB magic weapon
# 1
# PHB major image
# 1
# PHB mass cure wounds
# PHB mass heal
# HEREHEREHERE
# PHB mass healing word
# PHB mass suggestion
# 1
# PHB maze
# 1
# PHB meld into stone
# PHB melf's acid arrow
# 1
# PHB mending
# 1
# PHB message
# 1
# PHB meteor swarm
# 1
# PHB mind blank
# 1
# PHB minor illusion
# 1
# PHB mirage arcane
# 1
# PHB mirror image
# 1
# PHB mislead
# 1
# PHB misty step
# 1
# PHB modify memory
# 1
# PHB moonbeam
# PHB mordenkainen's faithful hound
# 1
# PHB mordenkainen's magnificent mansion
# 1
# PHB mordenkainen's private sanctum
# 1
# PHB mordenkainen's sword
# 1
# PHB move earth
# 1
# PHB nondetection
# 1
# PHB nystul's magic aura
# 1
# PHB otiluke's freezing sphere
# 1
# PHB otiluke's resilient sphere
# 1
# PHB otto's irresistible dance
# 1
# PHB pass without trace
# PHB passwall
# 1
# PHB phantasmal force
# 1
# PHB phantasmal killer
# 1
# PHB phantom steed
# 1
# PHB planar ally
# PHB planar binding
# 1
# PHB plane shift
# 1
# PHB plant growth
# PHB poison spray
# 1
# PHB polymorph
# 1
# PHB power word heal
# PHB power word kill
# 1
# PHB power word stun
# 1
# PHB prayer of healing
# PHB prestidigitation
# 1
# PHB prismatic spray
# 1
# PHB prismatic wall
# 1
# PHB produce flame
# PHB programmed illusion
# 1
# PHB project image
# 1
# PHB protection from energy
# 1
# PHB protection from evil and good
# 1
# PHB protection from poison
# PHB purify food and drink
# PHB raise dead
# PHB rary's telepathic bond
# 1
# PHB ray of enfeeblement
# 1
# PHB ray of frost
# 1
# PHB ray of sickness
# 1
# PHB regenerate
# PHB reincarnate
# PHB remove curse
# 1
# PHB resistance
# PHB resurrection
# PHB reverse gravity
# 1
# PHB revivify
# PHB rope trick
# 1
# PHB sacred flame
# PHB sanctuary
# PHB scorching ray
# 1
# PHB scrying
# 1
# PHB searing smite
# PHB see invisibility
# 1
# PHB seeming
# 1
# PHB sending
# 1
# PHB sequester
# 1
# PHB shapechange
# 1
# PHB shatter
# 1
# PHB shield
# 1
# PHB shield of faith
# PHB shillelagh
# PHB shocking grasp
# 1
# PHB silence
# PHB silent image
# 1
# PHB simulacrum
# 1
# PHB sleep
# 1
# PHB sleet storm
# 1
# PHB slow
# 1
# PHB spare the dying
# PHB speak with animals
# PHB speak with dead
# 2
# PHB speak with plants
# PHB spider climb
# 1
# PHB spike growth
# PHB spirit guardians
# PHB spiritual weapon
# PHB staggering smite
# PHB stinking cloud
# 1
# PHB stone shape
# 1
# PHB stoneskin
# 1
# PHB storm of vengeance
# PHB suggestion
# 1
# PHB sunbeam
# 1
# PHB sunburst
# 1
# PHB swift quiver
# PHB symbol
# 1
# PHB tasha's hideous laughter
# 1
# PHB telekinesis
# 1
# PHB telepathy
# 1
# PHB teleport
# 1
# PHB teleportation circle
# 1
# PHB tenser's floating disk
# 1
# PHB thaumaturgy
# PHB thorn whip
# PHB thunderous smite
# PHB thunderwave
# 1
# PHB time stop
# 1
# PHB tongues
# 1
# PHB transport via plants
# PHB tree stride
# PHB true polymorph
# 1
# PHB true resurrection
# PHB true seeing
# 1
# PHB true strike
# 1
# PHB tsunami
# PHB unseen servant
# 1
# PHB vampiric touch
# 1
# PHB vicious mockery
# PHB wall of fire
# 1
# PHB wall of force
# 1
# PHB wall of ice
# 1
# PHB wall of stone
# 1
# PHB wall of thorns
# PHB warding bond
# PHB water breathing
# 1
# PHB water walk
# PHB web
# 1
# PHB weird
# 1
# PHB wind walk
# PHB wind wall
# PHB wish
# 1
# PHB witch bolt
# 1
# PHB word of recall
# PHB wrathful smite
# PHB zone of truth
# SatO gate seal
# SatO warp sense
# SCC borrowed knowledge
# 1
# SCC kinetic jaunt
# 1
# SCC silvery barbs
# 1
# SCC vortex warp
# 1
# SCC wither and bloom
# 1
# TCE blade of disaster
# 2
# TCE booming blade
# 2
# TCE dream of the blue veil
# 2
# TCE green-flame blade
# 2
# TCE intellect fortress
# 2
# TCE lightning lure
# 2
# TCE mind sliver
# 2
# TCE spirit shroud
# 2
# TCE summon aberration
# 2
# TCE summon beast
# TCE summon celestial
# TCE summon construct
# 2
# TCE summon elemental
# 2
# TCE summon fey
# 2
# TCE summon fiend
# 2
# TCE summon shadowspawn
# 2
# TCE summon undead
# 2
# TCE sword burst
# 2
# TCE tasha's caustic brew
# 2
# TCE tasha's mind whip
# 2
# TCE tasha's otherworldly guise
# 2
# TDCSR freedom of the waves
# TDCSR freedom of the winds
# XGE abi-dalzim's horrid wilting
# 2
# XGE absorb elements
# 2
# XGE aganazzar's scorcher
# 2
# XGE beast bond
# XGE bones of the earth
# XGE catapult
# 2
# XGE catnap
# 2
# XGE cause fear
# 2
# XGE ceremony
# XGE chaos bolt
# XGE charm monster
# 2
# XGE control flames
# 2
# XGE control winds
# 2
# XGE create bonfire
# 2
# XGE create homunculus
# 2
# XGE crown of stars
# 2
# XGE danse macabre
# 2
# XGE dawn
# 2
# XGE dragon's breath
# 2
# XGE druid grove
# XGE dust devil
# 2
# XGE earth tremor
# 2
# XGE earthbind
# 2
# XGE elemental bane
# 2
# XGE enemies abound
# 2
# XGE enervation
# 2
# XGE erupting earth
# 2
# XGE far step
# 2
# XGE find greater steed
# XGE flame arrows
# 2
# XGE frostbite
# 2
# XGE guardian of nature
# XGE gust
# 2
# XGE healing spirit
# XGE holy weapon
# XGE ice knife
# 2
# XGE illusory dragon
# 2
# XGE immolation
# 2
# XGE infernal calling
# 2
# XGE infestation
# 2
# XGE investiture of flame
# 2
# XGE investiture of ice
# 2
# XGE investiture of stone
# 2
# XGE investiture of wind
# 2
# XGE invulnerability
# 2
# XGE life transference
# 2
# XGE maddening darkness
# 2
# XGE maelstrom
# XGE magic stone
# XGE mass polymorph
# 2
# XGE maximilian's earthen grasp
# 2
# XGE melf's minute meteors
# 2
# XGE mental prison
# 2
# XGE mighty fortress
# 2
# XGE mind spike
# 2
# XGE mold earth
# 2
# XGE negative energy flood
# 2
# XGE power word pain
# 2
# XGE primal savagery
# XGE primordial ward
# XGE psychic scream
# 2
# XGE pyrotechnics
# 2
# XGE scatter
# 2
# XGE shadow blade
# 2
# XGE shadow of moil
# XGE shape water
# 2
# XGE sickening radiance
# 2
# XGE skill empowerment
# 2
# XGE skywrite
# 2
# XGE snare
# 2
# XGE snilloc's snowball swarm
# 2
# XGE soul cage
# 2
# XGE steel wind strike
# 2
# XGE storm sphere
# 2
# XGE summon greater demon
# 2
# XGE summon lesser demons
# 2
# XGE synaptic static
# 2
# XGE temple of the gods
# XGE tenser's transformation
# 2
# XGE thunder step
# 2
# XGE thunderclap
# 2
# XGE tidal wave
# 2
# XGE tiny servant
# 2
# XGE toll the dead
# 2
# XGE transmute rock
# 2
# XGE vitriolic sphere
# 2
# XGE wall of light
# 2
# XGE wall of sand
# 2
# XGE wall of water
# 2
# XGE warding wind
# 2
# XGE watery sphere
# 2
# XGE whirlwind
# 2
# XGE word of radiance
# XGE wrath of nature
# XGE zephyr strike

# %%
len(Spell_info)
# Out:
# 341
