# %%
import json
import numpy as np
import re

# %%
def get_spells(spell_page):
    dic=spell_page.get('spells')
    if dic==None:
        return []
    spells=[spell.replace('{@spell ', '').replace('}', '') for level in dic.values() for spell in level.get('spells', [])]
    return spells

def get_daily(spell_page):
    dic=spell_page.get('daily')
    if dic==None:
        return []
    daily = []
    for lst in dic.values():
        for item in lst:
            s = item.get('entry') if isinstance(item, dict) else item
            if isinstance(s, str):
                m = re.search(r'\{([^}]*)\}', s)
                daily.append(re.sub(r'^@spell\s+', '', m.group(1)) if m else s)
            else:
                daily.append(item)
    return daily

def get_at_will(spell_page):
    dic=spell_page.get('will')
    if dic==None:
        return []
    wills = []
    for will in dic:
        s = will.get('entry') if isinstance(will, dict) else will
        if isinstance(s, str):
            m = re.search(r'\{([^}]*)\}', s)
            val = m.group(1) if m else s
            val = re.sub(r'^@spell\s+', '', val).strip()
            wills.append(val)
        else:
            wills.append(s)
    return wills

# %%
monster_path="./5etools/5etools-src/data/bestiary/"
monster_index=monster_path+"index.json"

with open(monster_index, "r") as f:
    monster_index_data = json.load(f)


monster_index_keys=list(monster_index_data.keys())
Monster_spells=[]
for book in monster_index_keys:
    if book=="XPHB" or book=="XMM" or book=="XDMG":
        continue
    book_file=monster_path+monster_index_data[book]
    with open(book_file, "r") as f:
        monster_data = json.load(f)



    # Load book monsters
    book_file=monster_path+monster_index_data[book]
    with open(book_file, "r") as f:
        monster_data = json.load(f)

    for mon in monster_data["monster"]:
        
        temp=mon.get("spellcasting")
        if temp==None:
            continue

        spells=get_spells(temp[0])
        #print(spells)
        at_will=get_at_will(temp[0])
        #print(at_will)
        daily=get_daily(temp[0])
        #print(daily)
        all_items = list(spells + at_will + daily)
        #print(all_items)
        #print("-------")
        print(all_items)
        Monster_spells.append(all_items)
# Out:
# ['detect magic', 'mage hand', 'prestidigitation', 'animate dead', 'dispel magic', 'speak with dead', 'finger of death', 'plane shift', 'project image']
# ['detect evil and good', 'mage armor', 'mage hand', 'protection from evil and good', 'remove curse', 'speak with dead', 'banishment', 'dispel evil and good']
# ['detect thoughts', 'augury']
# ['mage hand', 'message', 'vicious mockery', 'charm person', 'heroism', 'illusory script', 'sleep', 'unseen servant', 'cloud of daggers', 'invisibility']
# ['command', 'compelled duel', 'cure wounds', 'wrathful smite', 'aid', 'branding smite', 'lesser restoration', 'warding bond', 'zone of truth']
# ['fire bolt', 'light', 'mage hand', 'prestidigitation', 'detect magic', 'mage armor', 'distort value|AI*', 'gift of gab|AI*', 'suggestion', 'fast friends|AI*', 'lightning bolt', 'greater invisibility', 'cone of cold']
# ['fire bolt', 'friends', 'mage hand', 'minor illusion', 'prestidigitation', 'disguise self', "Jim's magic missile|AI*", 'mage armor', 'invisibility', "Jim's glowing coin|AI*", 'incite greed|AI*', 'fireball', 'conjure minor elementals', 'polymorph', 'mislead']
# ['dancing lights', 'disguise self', 'darkness', 'faerie fire']
# ['mage hand']
# ['guidance', 'sacred flame', 'spare the dying', 'thaumaturgy', 'bless', 'command', 'divine favor', 'shield of faith', 'enhance ability', 'hold person', 'magic weapon', 'silence', 'spiritual weapon', 'beacon of hope', "crusader's mantle", 'dispel magic', 'mass healing word', 'spirit guardians', 'death ward', 'freedom of movement', 'locate creature', 'stoneskin', 'dispel evil and good', 'flame strike', 'hold monster', 'greater restoration', 'legend lore']
# ['acid splash', 'light', 'mage hand', 'poison spray', 'shocking grasp', 'detect magic', 'mage armor', 'magic missile', 'sleep', 'blindness/deafness', 'cloud of daggers', 'scorching ray']
# ['guidance', 'light', 'mending', 'sacred flame', 'bane', 'cure wounds', 'guiding bolt', 'hold person', 'spiritual weapon']
# ['light', 'sacred flame', 'thaumaturgy', 'cure wounds', 'guiding bolt', 'sanctuary', 'lesser restoration', 'spiritual weapon', 'dispel magic', 'spirit guardians']
# ['minor illusion', 'sacred flame', 'thaumaturgy', 'command', 'darkness', 'darkvision', 'pass without trace', 'silence']
# ['druidcraft', 'produce flame', 'thorn whip', 'cure wounds', 'entangle', 'thunderwave', 'flame blade', 'moonbeam', 'pass without trace', 'call lightning', 'dispel magic', 'plant growth', 'blight', 'freedom of movement']
# ['detect magic', 'comprehend languages', 'tongues', 'conjure elemental', 'invisibility', 'major image', 'plane shift', 'wall of fire']
# ['acid splash', 'mage hand', 'poison spray', 'prestidigitation', 'mage armor', 'magic missile', 'unseen servant*', 'cloud of daggers*', 'misty step*', 'web*', 'fireball', 'thunder step|XGE*', "Evard's black tentacles*", 'stoneskin', 'cone of cold*', 'conjure elemental*']
# ['friends', 'mage hand', 'mending', 'message', 'charm person*', 'mage armor', 'magic missile', 'hold person*', 'invisibility', 'suggestion*', 'fireball', 'haste', 'tongues', 'arcane eye', 'phantasmal killer', 'hold monster*']
# ['banishment', 'detect thoughts', 'disguise self']
# ['fire bolt', 'light', 'mage hand', 'minor illusion', 'shocking grasp', 'mage armor', 'magic missile', 'shield', 'thunderwave', 'invisibility*', 'mirror image*', 'phantasmal force*', 'counterspell', 'fly', 'lightning bolt', 'major image*', 'banishment', 'hallucinatory terrain*', 'phantasmal killer*', 'stoneskin', 'conjure elemental', 'mislead*', 'telekinesis', 'disintegrate', 'plane shift', 'maze']
# ['dancing lights', 'minor illusion', 'vicious mockery']
# ['detect evil and good', 'detect magic', 'detect thoughts', 'bless', 'create food and water', 'cure wounds', 'lesser restoration', 'protection from poison', 'sanctuary', 'shield', 'dream', 'greater restoration', 'scrying']
# ['calm emotions', 'detect magic', 'sending']
# ['revivify', 'speak with plants']
# ['fly', 'mislead', 'sending']
# ['teleport']
# ['cure wounds', 'hold person', 'divination', 'sending', 'word of recall']
# ['compulsion', 'fear']
# ['druidcraft', 'guidance', 'pass without trace', 'resistance']
# ['detect thoughts']
# ['light', 'mage hand', 'plane shift', 'telekinesis']
# ['light', 'mage hand', 'detect magic', 'invisibility', 'mage armor', 'tongues', 'contact other plane', 'plane shift', 'telekinesis']
# ['druidcraft', 'light', 'mage hand', 'invisibility', 'pass without trace', 'dominate monster', 'forcecage', 'plane shift', 'telekinesis']
# ['detect magic', 'light', 'dimension door', 'invisibility', 'mage armor']
# ['arms of Hadar', 'detect magic', 'magic missile', "Tenser's floating disk", 'darkness', 'hold person', 'invisibility', 'spider climb', 'fear', 'hypnotic pattern', 'major image', 'stinking cloud']
# ['dimension door', 'invisibility']
# ['suggestion', 'disguise self', 'mage armor']
# ['disguise self', 'mage armor', 'dimension door', 'suggestion']
# ['suggestion', 'mage armor']
# ['light', 'mage hand', 'prestidigitation', 'dimension door', 'phantasmal force', 'mass suggestion', 'sending']
# ['friends', 'mage hand', 'prestidigitation', 'mirror image', 'spider climb']
# ['mage hand', 'invisibility']
# ['levitate', 'mage hand', 'freedom of movement', 'invisibility']
# ['mage hand', 'message', 'darkness', 'dimension door', 'fly', 'hypnotic pattern']
# ['wish']
# ['animate dead', 'branding smite', 'revivify', 'geas', 'raise dead']
# ['detect magic', 'fireball', 'dispel magic', 'hold monster', 'mirror image', 'mislead', 'raise dead', 'teleport', 'wall of fire', 'imprisonment', 'meteor swarm']
# ['guidance', 'sacred flame', 'thaumaturgy', 'bane', 'bless', 'cure wounds', 'guiding bolt (see "Actions" below)', 'blindness/deafness', 'hold person', 'silence', 'sending', 'spirit guardians']
# ['light', 'bless', 'cure wounds', 'protection from evil and good', 'banishment', 'heal', 'raise dead', 'shapechange', 'teleport']
# ['command', 'darkness', 'dispel evil and good', 'gate', 'harm', 'telekinesis', 'teleport', 'wind walk']
# ['chill touch', 'mending', 'resistance', 'sacred flame', 'spare the dying', 'thaumaturgy', 'cure wounds', 'detect evil and good', 'false life', 'inflict wounds', 'ray of sickness', 'blindness/deafness', 'gentle repose', 'hold person', 'ray of enfeeblement', 'spiritual weapon', 'animate dead', 'magic circle', 'speak with dead', 'spirit guardians', 'vampiric touch', 'banishment', 'blight', 'death ward', 'divination', 'locate creature', 'antilife shell', 'cloudkill', 'contagion', 'greater restoration', 'create undead', 'true seeing', 'divine word', 'regenerate']
# ['detect thoughts', 'disguise self', 'mage hand', 'minor illusion', 'charm person', 'detect magic', 'dispel magic', 'hellish rebuke', 'invisibility', 'major image', 'speak with dead', 'suggestion', 'banishment', 'demiplane', 'dominate person', 'fly', 'forcecage', 'geas', 'plane shift', 'true seeing']
# ['chill touch (see "Actions" below)', 'mage hand', 'message', 'prestidigitation', 'burning hands', 'detect magic', 'ray of sickness (see "Actions" below)', 'shield', 'darkness', 'misty step', 'scorching ray (see "Actions" below)', 'animate dead', 'fireball']
# ['charm person', 'disguise self', 'sanctuary']
# ['mage hand', 'message', 'prestidigitation', 'detect magic', 'protection from evil and good', 'ray of sickness (see "Actions" below)', 'shield', 'darkness', 'misty step']
# ['charm person', "Tasha's hideous laughter", 'confusion', 'enthrall', 'suggestion', 'hallucinatory terrain', "Otto's irresistible dance"]
# ['guidance', 'sacred flame (see "Actions" below)', 'thaumaturgy', 'command', 'detect evil and good', 'sanctuary']
# ['detect magic', 'fog cloud', 'light', 'minor illusion', 'dream', 'gaseous form', 'major image']
# ['detect magic', 'fog cloud', 'light', 'gaseous form', 'telekinesis']
# ['detect magic', 'mage armor', 'speak with dead', "Tenser's floating disk"]
# ['create or destroy water', 'detect magic', 'pass without trace']
# ['entangle', 'speak with animals', 'speak with plants', 'commune with nature', 'detect magic', 'disguise self']
# ['mage hand', 'minor illusion', "Tasha's hideous laughter", 'detect magic', 'disguise self', 'dispel magic', 'polymorph']
# ['mage armor', 'mage hand', 'prestidigitation', 'chain lightning', 'cone of cold', 'fireball', 'fly', 'plane shift']
# ['detect magic', 'levitate', 'mage hand', 'prestidigitation', 'detect thoughts', 'suggestion', 'telekinesis']
# ['druidcraft', 'guidance', 'stone shape', 'wall of stone']
# ['meld into stone', 'stone shape', 'wall of stone']
# ['detect magic', 'detect thoughts', 'control water', 'control weather', 'dispel magic', 'plane shift', 'sending', 'time stop']
# ['detect magic', 'detect thoughts', 'mage hand', 'control water', 'control weather', 'sending']
# ['Guidance', 'Light', 'Thaumaturgy', 'Bless', 'Freedom of Movement', 'Greater Restoration', 'Plane Shift', 'Protection from Evil and Good', 'Revivify']
# ['Detect Magic', 'Heat Metal', 'Darkness', 'Dispel Magic', 'Hold Person']
# ['Prestidigitation', 'Speak with Animals', 'Bestow Curse', 'Command', 'Crown of Madness']
# ['Druidcraft', 'Pass without Trace', 'Goodberry', 'Lesser Restoration', 'Locate Creature', 'Move Earth', 'Transport via Plants']
# ['Bless', 'Guidance', 'Silent Image', 'Bane', 'Bestow Curse', 'Divination', 'Scrying']
# ['Dancing Lights', 'Mage Hand', 'Prestidigitation', 'Slow', 'Bestow Curse', 'Dispel Magic']
# ['Detect Magic', 'Mage Armor', 'Blight', 'Blindness/Deafness', 'Cloudkill', 'Contagion']
# ['Light', 'Spare the Dying', 'Thaumaturgy', 'Mass Cure Wounds', 'Blade Barrier', 'Divination', 'Greater Restoration']
# ['Detect Thoughts', 'Mage Hand', 'Thaumaturgy', 'Dimension Door', 'Mass Suggestion']
# ['Charm Person', 'Teleport', 'Dispel Magic', 'Fog Cloud']
# ['Mage Hand', 'Thaumaturgy', 'Dimension Door', 'Divination', 'Enthrall']
# ['Cure Wounds', 'Divination', 'Greater Restoration']
# ['Mage Hand', "Tasha's Hideous Laughter"]
# ['Faerie Fire', 'Calm Emotions', 'Dispel Magic', 'Invisibility', 'Mass Cure Wounds', 'Revivify']
# ['Greater Restoration', 'Sending', 'Word of Recall']
# ['light', 'mage hand', 'prestidigitation', 'detect magic', 'dispel magic', 'faerie fire', 'hold monster', 'mind blank', 'teleport']
# ['fog cloud', 'control weather', 'telekinesis']
# ['sacred flame', 'thaumaturgy', 'command', 'guiding bolt', 'shield of faith', 'hold person', 'silence', 'spiritual weapon', 'animate dead', 'dispel magic', 'divination', 'guardian of faith', 'contagion', 'insect plague', 'harm']
# ['druidcraft', 'produce flame', 'shillelagh', 'entangle', 'longstrider', 'speak with animals', 'thunderwave', 'animal messenger', 'barkskin']
# ['druidcraft', 'detect magic', 'fog cloud', 'pass without trace', 'antilife shell', 'dispel magic', 'speak with plants', 'transport via plants', 'fire storm']
# ['light', 'mage hand', 'mending', 'prestidigitation', 'Shocking Grasp', 'comprehend languages', 'detect magic', 'dispel magic', 'identify', 'levitate', 'locate object', 'Shield', "Tenser's Floating Disk", 'unseen servant', 'banishment', 'contact other plane', "Drawmij's instant summons", 'legend lore', 'locate creature', 'planar binding', 'polymorph', 'protection from evil and good', 'scrying', 'sending', 'true seeing']
# ['dancing lights', 'mage hand', 'detect magic', 'detect thoughts', 'dispel magic', 'locate creature', 'dispel evil and good', 'wall of force']
# ['dispel magic', 'faerie fire', 'mirror image']
# ['light', 'sacred flame', 'thaumaturgy', 'command', 'inflict wounds', 'shield of faith', 'hold person', 'spiritual weapon']
# ['light', 'mage hand', 'mending', 'shocking grasp', 'comprehend languages', 'detect magic', 'identify', 'shield', 'dispel magic', 'levitate', 'locate object', 'see invisibility', 'sending', 'tongues', 'unseen servant']
# ['sacred flame', 'thaumaturgy', 'command', 'guiding bolt', 'shield of faith', 'hold person', 'silence', 'spiritual weapon', 'clairvoyance', 'dispel magic', 'divination', 'dimension door', 'contagion', 'scrying', 'harm']
# ['Bane', 'Bestow Curse', 'Command', 'Cure Wounds', 'Darkness', 'Lesser Restoration', 'Remove Curse', 'Antimagic Field', 'Earthquake', 'Flame Strike', 'Gate', 'Heal', 'Mass Heal', 'Wish']
# ['Animate Dead', 'Darkness', 'Detect Evil and Good', 'Detect Magic', 'Dispel Evil and Good', 'Hallow', 'Hold Monster', 'Suggestion', 'Teleport', 'True Seeing', 'Symbol', 'Wish']
# ['Detect Magic', 'Fireball', 'Dispel Magic', 'Hold Monster', 'Mirror Image', 'Mislead', 'Raise Dead', 'Teleport', 'Wall of Fire', 'Imprisonment', 'Meteor Swarm']
# ['Bestow Curse', 'Command', 'Darkness', 'Hold Monster', 'Major Image', 'Antilife Shell', 'Incendiary Cloud', 'Scrying', 'Weird']
# ['Detect Magic', 'Dispel Magic', 'Heroism', 'Magic Missile', "Evard's Black Tentacles", 'Cone of Cold', 'Confusion', 'Dimension Door', 'Geas', 'Invisibility', 'Prismatic Wall', 'Slow']
# ['Bless', 'Detect Evil and Good', 'Foresight', 'Commune', 'Heal', 'Legend Lore', 'Raise Dead', 'Scrying']
# ['False Life', 'Gentle Repose', 'Lesser Restoration', 'Protection from Evil and Good', 'Speak with Dead', 'Antilife Shell', 'Blight', 'Death Ward', 'Dispel Evil and Good', 'Greater Restoration', 'Raise Dead', 'Regenerate', 'Revivify', 'Spiritual Weapon']
# ['Cone of Cold', 'Darkness', 'Ice Storm', 'Wall of Ice']
# ['Darkness', 'Detect Evil and Good', 'Detect Magic', 'Dispel Magic', 'Geas', 'Greater Restoration', 'Hallow', 'Hold Monster', 'Locate Creature', 'Locate Object', 'Major Image', 'Resurrection', 'Scrying', 'Suggestion', 'Wall of Fire', 'Meteor Swarm', 'Symbol', 'Wish']
# ['Aura of Purity', 'Compelled Duel', "Crusader's Mantle", 'Death Ward', 'Dispel Evil and Good', 'Find Steed', 'Lesser Restoration', 'Remove Curse', 'Revivify', 'Shield of Faith']
# ['Resistance', 'Thaumaturgy', 'Animate Dead', 'Antimagic Field', 'Astral Projection', 'Blade Barrier', 'Command', 'Contagion', 'Dispel Magic', 'Divination', 'Etherealness', 'Fire Storm', 'Harm', 'Hold Person', 'Silence']
# ['Bane', 'Disguise Self', 'Dispel Magic', 'Mage Armor', 'Mirror Image', 'Thaumaturgy', 'Bestow Curse', 'Blindness/Deafness', 'Blink', 'Charm Person', 'Contagion', 'Dimension Door', 'Dominate Person', 'Hold Person', 'Pass Without Trace', 'Polymorph', 'Teleport']
# ['Alter Self', 'Detect Evil and Good', 'Fireball', 'Invisibility', 'Major Image', 'Wall of Fire', 'Blade Barrier', 'Dispel Evil and Good', 'Finger of Death']
# ['Arcane Eye', 'Detect Magic', 'Detect Thoughts', 'Fly', 'Light', 'Locate Object', 'Mage Armor', 'Mage Hand', 'Message', 'Prestidigitation', 'Cone of Cold', 'Foresight', 'Stoneskin', "Rary's telepathic bond", 'True Seeing']
# ['acid splash', 'fire bolt', 'light', 'mage hand', 'prestidigitation', 'detect magic', 'magic missile', 'sleep', 'witch bolt', 'crown of madness', 'enlarge/reduce', 'misty step', 'dispel magic', 'fireball', 'lightning bolt', 'blight', "Evard's black tentacles", 'polymorph', 'cloudkill', 'geas', 'scrying', 'programmed illusion', 'true seeing', 'finger of death', 'mirage arcane', 'power word stun']
# ['mage hand', 'prestidigitation', 'ray of frost', 'ray of sickness', 'sleep', "Tasha's hideous laughter", 'alter self', 'invisibility']
# ['mage hand', 'prestidigitation', 'ray of frost']
# ['fire bolt', 'light', 'mage hand', 'prestidigitation', 'protection from evil and good', 'magic missile', 'shield', 'darkvision', 'knock', 'mirror image', 'clairvoyance', 'lightning bolt', 'magic circle', 'greater invisibility']
# ['counterspell', 'crown of madness', 'hypnotic pattern', 'telekinesis']
# ['fire bolt', 'light', 'mage hand', 'prestidigitation', 'detect magic', 'mage armor', 'magic missile', 'shield', 'misty step', 'suggestion', 'counterspell', 'fireball', 'fly', 'greater invisibility', 'ice storm', 'cone of cold']
# ['light', 'mending', 'thaumaturgy', 'command', 'purify food and drink', 'sanctuary', 'augury', 'gentle repose', 'hold person', 'animate dead', 'create food and water']
# ['light', 'mending', 'sacred flame', 'thaumaturgy', 'bane', 'command', 'detect evil and good', 'protection from evil and good', 'lesser restoration', 'protection from poison', 'spiritual weapon', 'create food and water', 'speak with dead', 'spirit guardians', 'divination', 'freedom of movement', 'guardian of faith', 'greater restoration', 'raise dead', 'find the path', 'harm', 'true seeing', 'fire storm', 'regenerate', 'earthquake']
# ['magic weapon', 'nondetection', 'misty step', 'phantom steed']
# ['guidance', 'light', 'mending', 'thaumaturgy', 'cure wounds', 'detect evil and good', 'protection from evil and good', 'sanctuary', 'augury', 'lesser restoration', 'protection from poison', 'magic circle', 'remove curse', 'speak with dead', 'death ward', 'freedom of movement', 'dispel evil and good']
# ['command', 'divine favor', 'thunderous smite', 'branding smite', 'magic weapon', 'blinding smite', 'dispel magic', 'staggering smite']
# ['friends', 'light', 'mage hand', 'prestidigitation', 'charm person', 'mage armor', 'shield', 'sleep', 'misty step', 'suggestion', 'bestow curse', 'phantom steed', 'vampiric touch', 'greater invisibility', 'stoneskin', 'dominate person']
# ['mage hand', 'prestidigitation', 'ray of frost', 'comprehend languages', 'fog cloud', 'sleep', 'detect thoughts', 'gust of wind', 'mirror image', 'animate dead', 'fireball', 'nondetection', 'blight', 'greater invisibility', 'polymorph', 'animate objects', 'scrying']
# ['fire bolt', 'light', 'mage hand', 'prestidigitation', 'shocking grasp', 'detect magic', 'mage armor', 'magic missile', 'shield', 'mirror image', 'misty step', 'web', 'counterspell', 'fly', 'lightning bolt', "Mordenkainen's faithful hound", 'polymorph', 'stoneskin', "Bigby's hand", 'cone of cold', 'scrying', 'true seeing', "Mordenkainen's magnificent mansion", 'mind blank', 'time stop', 'disguise self', 'invisibility']
# ['guidance', 'light', 'lesser restoration', 'remove curse', 'water breathing']
# ['animal friendship', 'goodberry']
# ['animal friendship', 'goodberry', 'pass without trace']
# ['animal friendship', 'freedom of movement', 'goodberry', 'pass without trace', 'protection from energy']
# ['guidance', 'light', 'spare the dying', 'bless', 'cure wounds']
# ['guidance', 'light', 'spare the dying', 'revivify', 'bless', 'cure wounds']
# ['guidance', 'light', 'spare the dying', 'revivify', 'bless', 'cure wounds']
# ['minor illusion', 'mage armor', 'major image', 'phantasmal force']
# ['mage armor', 'mage hand', 'longstrider']
# ['mage armor', 'mage hand', 'longstrider', 'scrying', 'slow']
# ['mage hand', 'longstrider', 'scrying', 'slow', 'telekinesis', 'water breathing']
# ['alter self', 'light', 'mage hand', 'comprehend languages', 'mage armor', 'zone of truth']
# ['light', 'sacred flame', 'thaumaturgy', 'command', 'inflict wounds', 'shield of faith', 'hold person', 'spiritual weapon']
# ['detect magic', 'detect thoughts', 'identify', 'scrying']
# ['disguise self', 'detect thoughts', 'invisibility', 'dimension door', 'zone of truth']
# ['minor illusion', 'mage armor', 'major image', 'phantasmal force']
# ['light', 'mage hand', 'detect magic', 'levitate']
# ['dimension door', 'charm person', 'mage armor', 'sending']
# ['dancing lights', 'mage hand', 'comprehend languages', 'identify', 'mage armor']
# ['alter self', 'light', 'mage hand', 'comprehend languages', 'mage armor', 'zone of truth']
# ['chill touch', 'blindness/deafness', 'ray of sickness']
# ['dancing lights', 'darkness', 'faerie fire', 'levitate']
# ['guidance', 'light', 'resistance', 'sacred flame', 'spare the dying', 'bless', 'cure wounds', 'shield of faith', 'aid', 'lesser restoration', 'protection from energy', 'revivify', 'banishment', 'death ward', 'greater restoration', 'mass cure wounds', 'heal']
# ['fire bolt', 'light', 'mage hand', 'minor illusion', 'shocking grasp', 'burning hands', 'shield', 'sleep', 'flaming sphere', 'invisibility', 'fireball', 'fly', 'polymorph', 'wall of fire', 'cone of cold', 'hold monster', 'chain lightning']
# ['thunderwave', 'augury', 'bless', 'lightning bolt', 'revivify']
# ['mage hand', 'prestidigitation', 'ray of frost (see "Actions" below)', 'detect magic', 'mage armor', 'magic missile (see "Actions" below)', 'shield']
# ['wall of stone', 'greater restoration']
# ['faerie fire', 'speak with animals', 'animal friendship', 'create food and water', 'revivify', 'awaken', 'pass without trace']
# ['thunderwave', 'light', 'ray of frost']
# ['invisibility', 'mage hand', 'dominate person', 'dimension door', 'disguise self', 'sending']
# ['enlarge/reduce', 'invisibility', 'stinking cloud', 'web']
# ['cure wounds', 'guidance', 'sacred flame']
# ['light', 'spare the dying', 'thaumaturgy', 'blade barrier', 'dispel magic', 'flame strike', 'lesser restoration', 'revivify']
# ['detect magic', 'light', 'prestidigitation', 'dimension door', 'mage armor', 'arcane eye', 'dominate person', 'wall of force']
# ['command', 'banishment', 'dispel magic', 'hold person']
# ['healing word', 'druidcraft', 'poison spray']
# ['dispel magic', 'wall of stone']
# ['counterspell', 'detect magic', 'dispel magic', 'see invisibility', 'antimagic field']
# ['hex']
# ['eldritch blast', 'false life', 'mage armor', 'mage hand', 'charm person', 'hex', 'hold person', 'invisibility']
# ['druidcraft', 'minor illusion', 'shocking grasp', 'cure wounds', 'fog cloud', 'thunderwave', 'hold person', 'mirror image', 'misty step', 'dispel magic', 'lightning bolt (see "Actions" below)', 'sleet storm']
# ['friends']
# ['light', 'sacred flame', 'spare the dying', 'command', 'cure wounds', 'guiding bolt', 'lesser restoration', 'spiritual weapon', 'dispel magic', 'revivify']
# ['eldritch blast', 'minor illusion', 'armor of Agathys', 'arms of Hadar', 'counterspell', 'crown of madness', 'invisibility', 'hunger of Hadar']
# ['witch bolt', 'bestow curse', 'fear', 'thunderwave']
# ['produce flame', 'resistance', 'thorn whip', 'entangle', 'fog cloud', 'blindness/deafness', 'spike growth', 'animate dead', 'conjure animals (reptiles only)']
# ['command', 'compelled duel', 'hellish rebuke', 'wrathful smite', 'branding smite', 'crown of madness', 'darkness', 'find steed', 'magic weapon']
# ['detect magic', 'disguise self', 'dream', 'hypnotic pattern', 'sleep', 'legend lore', 'scrying']
# ['charm person', 'dominate person', 'dream', 'detect thoughts', 'disguise self', 'suggestion']
# ['mage hand', 'vicious mockery', 'charm person', 'dissonant whispers', 'hex', 'hold person', 'mage armor']
# ['arcane eye', 'clairvoyance', 'confusion', 'dream', 'eyebite']
# ['chill touch (see "Actions" below)', 'fire bolt', 'mage hand', 'prestidigitation', 'ray of frost', 'magic missile', 'shield', 'sleep', 'blur', 'detect thoughts', 'mirror image', 'animate dead', 'counterspell', 'fireball', 'fly', 'lightning bolt', 'blight', 'confusion', 'polymorph', 'cloudkill', 'cone of cold', 'hold monster', 'scrying', 'chain lightning', 'circle of death', 'create undead', 'finger of death', 'forcecage', 'prismatic spray', 'incendiary cloud', 'maze', 'power word kill', 'time stop']
# ['mage hand', 'prestidigitation']
# ['chromatic orb', 'detect thoughts', 'disguise self', 'banishing smite', 'destructive wave', 'fly', 'mass suggestion', 'staggering smite', 'suggestion', 'true seeing']
# ['charm person', 'cure wounds', 'disguise self', 'thaumaturgy', 'commune', 'dominate person', 'insect plague', 'mass suggestion', 'raise dead']
# ['detect thoughts', 'dispel magic', 'spirit guardians', 'banishing smite', 'blinding smite', 'staggering smite']
# ['counterspell', 'detect magic', 'detect thoughts', 'dispel magic', 'eyebite', 'fireball', 'lightning bolt', 'shield', 'chain lightning', 'create undead', 'dream', 'hold monster', 'mass suggestion', 'scrying', 'foresight', 'gate', 'power word kill', 'teleport']
# ['fire bolt', 'chromatic orb']
# ['fire bolt (see "Actions" below)', 'mage hand', 'mending', 'prestidigitation', 'expeditious retreat', 'sanctuary', 'thunderwave', 'blur', 'heat metal', 'scorching ray', 'see invisibility', 'dispel magic', 'fly', 'haste', 'freedom of movement', "Mordenkainen's faithful hound", 'animate objects', 'wall of force']
# ['charm person', 'fear']
# ['guidance', 'mending', 'sacred flame', 'spare the dying', 'thaumaturgy', 'bless', 'command', 'create or destroy water', 'augury', 'calm emotions', 'hold person', 'daylight', 'dispel magic', 'spirit guardians', 'banishment', 'divination', 'guardian of faith', 'dispel evil and good', 'flame strike (see "Actions" below)', 'scrying', 'forbiddance', 'planar ally', 'plane shift']
# ['detect thoughts', 'disguise self', 'shield']
# ['guidance', 'sacred flame', 'cure wounds']
# ['blink', 'control water', 'dispel magic', 'protection from evil and good', 'sending']
# ['dancing lights', 'guidance', 'command', 'divination', 'hypnotic pattern', 'lesser restoration']
# ['mage hand', 'minor illusion', 'detect thoughts', 'dispel magic', 'invisibility', 'major image']
# ['faerie fire', 'calm emotions', 'invisibility', 'revivify']
# ['dissonant whispers', 'hold monster', 'meld into stone', 'telekinesis']
# ['bane', 'control water', 'create or destroy water']
# ['protection from evil and good', "Tenser's floating disk", 'unseen servant']
# ['dispel magic', 'forcecage', 'plane shift', 'reverse gravity', 'time stop']
# ['blink', 'control water', 'dispel magic', 'freedom of movement', 'globe of invulnerability', 'plane shift', 'protection from evil and good', 'sending']
# ['dancing lights', 'guidance', 'command', 'divination', 'greater restoration', 'hypnotic pattern', 'invisibility']
# ['mage hand', 'minor illusion', 'detect thoughts', 'dispel magic', 'etherealness', 'major image', 'mislead']
# ['faerie fire', 'calm emotions', 'dispel magic', 'invisibility', 'revivify']
# ['dissonant whispers', 'hold monster', 'meld into stone', 'telekinesis', 'teleport']
# ['antilife shell', 'bane', 'control water', 'create or destroy water']
# ['dancing lights', 'guidance']
# ['dispel magic', 'forcecage', 'plane shift', 'reverse gravity', 'time stop']
# ['enlarge/reduce', 'invisibility', 'stinking cloud']
# ['invisibility', 'mage hand', 'dimension door', 'disguise self', 'sending']
# ['detect thoughts', 'invisibility', 'telekinesis']
# ['light', 'thaumaturgy', 'enhance ability', 'flame strike', 'mass cure wounds', 'revivify', 'tongues']
# ['dancing lights', 'calm emotions', 'charm person', 'command', 'comprehend languages']
# ["Bigby's hand", 'hypnotic pattern', 'telekinesis']
# ['mage hand', 'minor illusion']
# ['dispel magic', 'forcecage', 'plane shift', 'reverse gravity', 'time stop']
# ['alarm', "Tenser's floating disk"]
# ['dispel magic', 'forcecage', 'plane shift', 'reverse gravity', 'time stop']
# ['bane']
# ['dispel magic', 'forcecage', 'plane shift', 'reverse gravity', 'time stop']
# ['blink', 'dispel magic', 'protection from evil and good', 'sending']
# ['dancing lights', 'guidance', 'hypnotic pattern', 'lesser restoration']
# ['mage hand', 'minor illusion', 'detect thoughts', 'invisibility', 'silent image']
# ['calm emotions', 'faerie fire']
# ['dissonant whispers', 'hold person', 'meld into stone']
# ['bane', 'create or destroy water']
# ['calm emotions', 'command', 'compelled duel']
# ['acid splash', 'light', 'mending', 'poison spray', 'shocking grasp', 'detect magic', 'grease', 'shield', 'alter self', 'darkvision', 'enlarge/reduce', 'hold person', 'counterspell', 'dispel magic', 'haste', 'protection from energy', 'confusion', 'conjure minor elementals', 'polymorph', 'cone of cold', 'creation', 'hold monster', 'move earth', 'wall of ice', 'prismatic spray', 'control weather']
# ['alter self', 'detect magic', 'eldritch blast', 'false life', 'levitate', 'mage armor', 'circle of death', 'enthrall', 'suggestion', 'hellish rebuke', 'hex', 'scorching ray']
# ['fire bolt', "Tasha's hideous laughter"]
# ['druidcraft', 'dispel magic', 'entangle', 'plant growth', 'spike growth', 'moonbeam', 'grasping vine', 'wall of thorns']
# ['fireball', 'scorching ray', 'shield', 'thunderwave']
# ['enlarge/reduce', 'mage armor', 'scorching ray', 'counterspell', 'dispel magic', 'protection from energy']
# ['command', 'detect evil and good', 'raise dead', 'charm person', 'darkness', 'suggestion']
# ['acid splash', 'chill touch', 'mage hand', 'poison spray', 'prestidigitation', 'chromatic orb', 'magic missile', 'ray of sickness', "Melf's acid arrow", 'ray of enfeeblement', 'spider climb', 'web', 'animate dead', 'bestow curse', 'fear', 'vampiric touch', 'blight', "Evard's black tentacles", 'cloudkill', 'insect plague', 'circle of death', 'create undead', 'finger of death']
# ['druidcraft', 'produce flame', 'resistance', 'thorn whip', 'cure wounds', 'faerie fire', 'thunderwave', 'beast sense', 'flame blade', 'pass without trace', 'conjure animals', 'dispel magic', 'plant growth', 'dominate beast', 'freedom of movement', 'wall of fire', 'commune with nature', 'conjure elemental', 'scrying', 'transport via plants', 'wall of thorns']
# ['fire bolt', 'light', 'sacred flame', 'spare the dying', 'guiding bolt', 'healing word', 'heroism', 'shield of faith', 'lesser restoration', 'scorching ray', 'blinding smite', "crusader's mantle", 'revivify', 'banishment', 'wall of fire', 'flame strike']
# ['compelled duel', 'guiding bolt', 'daylight', 'fireball']
# ['mage armor', 'scorching ray', 'banishment', 'cone of cold', 'dimension door', 'fireball', 'ice storm']
# ['mending', 'resistance', 'spare the dying', 'cure wounds', 'sanctuary', 'aid', 'lesser restoration']
# ['stoneskin', 'levitate', 'lightning bolt', 'thunderwave']
# ['poison spray', 'shillelagh', 'thorn whip', 'cure wounds', 'entangle', 'ray of sickness', 'pass without trace', 'ray of enfeeblement', 'spike growth', 'animate dead', 'dispel magic', 'plant growth', 'blight', 'giant insect']
# ['bless', 'conjure animals']
# ['imprisonment']
# ['acid splash', 'chill touch', 'mage hand', 'poison spray', 'prestidigitation', 'entangle', 'ray of sickness', 'sleep', "Melf's acid arrow", 'ray of enfeeblement', 'spider climb', 'web', 'animate dead', 'plant growth', 'vampiric touch', 'blight', 'giant insect', 'grasping vine', 'cloudkill', 'insect plague', 'circle of death', 'create undead', 'finger of death', 'forcecage']
# ['chill touch', 'poison spray', 'ray of enfeeblement', 'ray of sickness', 'animate dead', 'blight', 'vampiric touch']
# ['fire bolt', 'friends', 'light', 'message', 'alarm', 'expeditious retreat', 'shield', 'arcane lock', 'detect thoughts', 'hold person', 'clairvoyance', 'dispel magic', 'slow', 'locate creature', 'stoneskin']
# ['detect thoughts', 'encode thoughts|GGR', 'freedom of movement', 'vicious mockery', 'blur', 'confusion', 'mirror image', 'modify memory', "Rary's telepathic bond"]
# ['charm person', 'crown of madness', 'dominate person']
# ['message', 'charm person', 'hold person', 'mirror image', 'sleep', 'gaseous form', 'major image']
# ['encode thoughts|GGR', 'friends', 'charm person', 'detect thoughts', 'mage armor', 'sleep', 'suggestion', 'dominate person', 'mass suggestion', 'modify memory']
# ['fire bolt', 'light', 'prestidigitation', 'ray of frost', 'shocking grasp', 'detect magic', 'magic missile', 'shield', 'thunderwave', 'unseen servant', 'blur', 'enlarge/reduce', 'flaming sphere', 'hold person', 'scorching ray', 'counterspell', 'fireball', 'lightning bolt', 'slow', 'confusion', 'dimension door', 'fabricate', 'conjure elemental', 'polymorph', 'wall of fire', 'wall of force', 'chain lightning', 'disintegrate', 'true seeing', 'project image', 'reverse gravity', 'teleport', 'control weather', 'maze', 'power word stun', 'prismatic wall']
# ['chill touch', 'sanctuary', 'spirit guardians']
# ['detect thoughts', 'mage armor', 'clairvoyance', 'locate object']
# ['hellish rebuke']
# ['dancing lights', 'minor illusion', 'vicious mockery', 'bane', 'dissonant whispers', 'silent image', "Tasha's hideous laughter", 'thunderwave', 'crown of madness', 'enthrall', 'suggestion']
# ['blade ward', 'light', 'message', 'shocking grasp', 'guiding bolt', 'shield', 'thunderwave', 'witch bolt', 'blur', 'levitate', 'lightning bolt']
# ['clairvoyance', 'crown of madness', 'major image', 'suggestion', 'confusion', 'mass suggestion']
# ['friends', 'mage hand', 'message', 'command', 'ensnaring strike', 'shield', 'calm emotions', 'hold person', 'suggestion', 'clairvoyance', 'counterspell', 'dispel magic', 'banishment', 'divination', 'dominate person']
# ['charm person', 'disguise self', 'encode thoughts|GGR', 'blur', 'detect thoughts', 'gaseous form']
# ['dispel magic', 'druidcraft', 'bless', 'conjure animals', 'giant insect', 'moonbeam', 'plant growth', 'spike growth', 'suggestion', 'conjure fey', 'mass cure wounds']
# ['expeditious retreat', 'fog cloud', 'misty step']
# ['acid splash', 'druidcraft', 'ray of frost', 'shape water|XGE', 'color spray', 'expeditious retreat', 'fog cloud', 'shield', 'enlarge/reduce', 'gust of wind', 'counterspell', 'fly', 'slow', 'control water', 'ice storm', 'polymorph', 'conjure elemental', 'creation', 'move earth', 'wall of ice', 'prismatic spray', 'teleport', 'control weather', 'dominate monster']
# ['fog cloud']
# ['light', 'sacred flame', 'spare the dying', 'thaumaturgy', 'command', 'guiding bolt', 'purify food and drink', 'hold person', 'lesser restoration', 'silence', 'bestow curse', 'dispel magic']
# ['detect magic', 'detect thoughts', 'invisibility', 'fear', 'fireball', 'fly', 'cloudkill', 'etherealness']
# ['friends', 'mage hand', 'prestidigitation', 'ray of frost', 'disguise self', 'fog cloud', 'mage armor', 'witch bolt', 'gust of wind', "Melf's acid arrow", 'misty step']
# ['chill touch', 'mage hand', 'minor illusion', 'prestidigitation', 'ray of frost', 'expeditious retreat', 'magic missile', 'shield', 'blur', 'hold person', 'sleet storm']
# ['guidance', 'mending', 'resistance', 'thaumaturgy', 'bless', 'detect magic', 'guiding bolt', 'hold person', 'spiritual weapon (trident)', 'bestow curse', 'fear', 'mass healing word', 'tongues', 'banishment']
# ['message', 'comprehend languages']
# ['dancing lights', 'minor illusion', 'ray of frost', 'charm person', 'color spray', 'magic missile', 'silent image', 'magic mouth', 'scorching ray']
# ['animal messenger', 'beast sense', 'speak with animals', 'cure wounds', 'entangle', 'faerie fire', 'thunderwave']
# ['friends', 'message', 'suggestion', 'charm person', 'disguise self']
# ['mage hand', 'minor illusion', 'prestidigitation', 'speak with dead', 'fog cloud', 'mage armor', 'magic missile', 'spider climb', "Bigby's hand", 'major image']
# ['mage hand', 'message', 'prestidigitation', 'bestow curse', "Bigby's hand", 'dimension door', 'mage armor', "Otiluke's resilient sphere", 'thunderwave', "Evard's black tentacles", 'finger of death', 'time stop']
# ['light', 'mage hand', 'shocking grasp', 'charm person', 'magic missile', 'hold person', 'misty step']
# ['minor illusion', 'Fire Bolt', 'grease', 'Burning Hands']
# ['guidance', 'Sacred Flame', 'cure wounds']
# ['mage hand', 'prestidigitation', 'ray of frost', 'shocking grasp', 'fog cloud', 'magic missile', 'shield', 'thunderwave', 'invisibility', 'misty step', 'scorching ray', 'counterspell', 'dispel magic', 'fireball']
# ['fog cloud', 'levitate']
# ['fire bolt', 'prestidigitation', 'shocking grasp', 'longstrider', 'magic missile', 'shield', 'thunderwave', 'magic weapon', 'misty step']
# ['light', 'sacred flame', 'thaumaturgy', 'command', 'cure wounds', 'healing word', 'sanctuary', 'calm emotions', 'hold person', 'spiritual weapon', 'mass healing word', 'spirit guardians']
# ['mage hand', 'minor illusion', 'prestidigitation', 'ray of frost', 'charm person', 'color spray', 'disguise self', 'longstrider']
# ['druidcraft', 'guidance', 'poison spray', 'cure wounds', 'entangle', 'healing word', 'thunderwave', 'barkskin', 'beast sense', 'spike growth', 'plant growth', 'water walk']
# ['fire bolt', 'minor illusion', 'prestidigitation', 'shocking grasp', 'chromatic orb', 'color spray', 'mage armor', 'magic missile', 'detect thoughts', 'mirror image', 'phantasmal force', 'counterspell', 'fireball', 'major image', 'confusion', 'greater invisibility', 'mislead', 'seeming', 'globe of invulnerability']
# ['guidance', 'resistance', 'thaumaturgy', 'command', 'cure wounds', 'healing word', 'inflict wounds', 'blindness/deafness', 'lesser restoration', 'spiritual weapon (spear)', 'dispel magic', 'mass healing word', 'sending', 'death ward', 'freedom of movement', 'insect plague']
# ['chromatic orb', 'detect magic', 'misty step', 'control weather', 'detect thoughts', 'ice storm']
# ['fire bolt (see "Actions" below)', 'mage hand', 'message', 'minor illusion', 'prestidigitation', 'detect magic', 'mage armor', 'magic missile', 'flaming sphere', 'knock', 'scorching ray', 'counterspell', 'fireball', 'fly', 'banishment', 'fire shield', "Bigby's hand", "Rary's telepathic bond"]
# ['acid splash *', 'light', 'minor illusion', 'shocking grasp *', 'detect magic', 'disguise self', 'magic missile *', 'invisibility', 'levitate', 'phantasmal force', 'fireball', 'sending', 'slow', 'arcane eye', 'confusion', 'animate objects', 'Shocking Grasp', 'Acid Splash']
# ['acid splash*', 'light', 'minor illusion', 'shocking grasp*', 'detect magic', 'disguise self', 'magic missile*', 'invisibility', 'levitate', 'phantasmal force']
# ['druidcraft', 'guidance', 'resistance', 'animal friendship', 'fog cloud', 'speak with animals', 'animal messenger', 'moonbeam', 'pass without trace', 'conjure animals', 'sleet storm', 'wind wall', 'hallucinatory terrain', 'ice storm', 'awaken']
# ['detect thoughts', 'levitate', 'dominate monster', 'plane shift']
# ['levitate']
# ['druidcraft', 'mending', 'poison spray', 'detect magic', 'enlarge/reduce', 'faerie fire', 'invisibility', 'polymorph', 'stoneskin']
# ['mage hand', 'message', 'prestidigitation', 'ray of frost', 'detect magic', 'thunderwave', 'counterspell']
# ['light*', 'message*', 'prestidigitation', 'shocking grasp (see "Actions" below)', 'mage armor*', 'shield', 'sleep', 'arcane lock*', 'detect thoughts*', 'suggestion*', 'counterspell', 'lightning bolt*']
# ['misty step']
# ['fire bolt', 'mage hand', 'shocking grasp', 'silent image', 'chromatic orb', 'crown of madness', 'shield']
# ['chill touch (see "Actions" below)', 'light', 'mage hand', 'message', 'prestidigitation', 'comprehend languages', 'detect magic', 'ray of sickness', "Tasha's hideous laughter", 'darkvision', 'hold person', 'ray of enfeeblement', 'animate dead', "Leomund's tiny hut", 'vampiric touch (see "Actions" below)', 'arcane eye', 'blight']
# ['animal messenger', 'fog cloud', 'freedom of movement', 'pass without trace', 'silence', 'water walk']
# ['eldritch blast', 'mage hand', 'hold person', 'suggestion']
# ['ensnaring strike', 'hail of thorns', "hunter's mark", 'locate animals or plants']
# ['light']
# ['dancing lights', 'light', 'message', 'shocking grasp', 'comprehend languages', 'cure wounds', 'grease', 'identify', 'detect thoughts', 'invisibility', 'heat metal', 'dispel magic', 'flame arrows|XGE', 'hypnotic pattern', 'fabricate', 'stone shape', 'stoneskin', 'creation']
# ['detect thoughts', 'command', 'hold person']
# ['light', 'mending', 'message', 'shocking grasp', 'alarm', 'cure wounds', 'identify', 'ray of sickness', 'invisibility', "Melf's acid arrow", 'web', 'dispel magic', 'haste', 'stinking cloud', 'blight', "Mordenkainen's faithful hound", "Otiluke's resilient sphere", 'cloudkill']
# ['detect evil and good', 'cure wounds', 'lesser restoration', 'commune', 'dispel evil and good']
# ['control water', 'fog cloud', 'greater restoration']
# ['dancing lights', 'mage hand', 'mage armor', 'dispel magic', 'invisibility', 'polymorph']
# ['light', 'minor illusion', 'prestidigitation', 'detect magic', 'fog cloud', 'phantasmal force', 'shatter']
# ['project image', 'blindness/deafness', 'blur']
# ['arms of Hadar', 'charm person', 'mage armor']
# ['mage hand', 'prestidigitation', 'charm person', 'faerie fire', 'unseen servant']
# ['nondetection', 'dimension door', 'blindness/deafness', 'blur']
# ['detect thoughts', 'mage hand', 'zone of truth', 'charm person', 'command', 'hold person', 'compulsion', 'hold monster', 'sleep', "Tasha's hideous laughter"]
# ['blade ward', 'vicious mockery', 'charm person', 'detect magic', 'disguise self', 'identify', "Tasha's hideous laughter"]
# ['light']
# ['chill touch', 'eldritch blast', 'mage hand', 'darkness', 'hex', 'hypnotic pattern', 'misty step', 'phantasmal force', 'unseen servant']
# ['light', 'mage hand', 'shocking grasp', 'charm person', 'magic missile', 'hold person', 'misty step']
# ['dancing lights', 'darkness', 'faerie fire']
# ['mage hand', 'minor illusion', 'magic missile', 'unseen servant']
# ['guidance', 'mending', 'shape water|XGE', 'shillelagh', 'absorb elements|XGE', 'cure wounds', 'entangle', 'speak with animals', 'darkvision', 'hold person', 'lesser restoration', 'moonbeam', 'conjure animals', 'dispel magic', 'water breathing', 'charm monster|XGE', 'freedom of movement', 'greater restoration', 'mass cure wounds', 'conjure fey']
# ['frostbite|XGE', 'mending', 'resistance', 'shape water|XGE', 'thunderclap|XGE*', 'create or destroy water', 'charm person', 'cure wounds', 'thunderwave', 'darkvision', 'hold person', 'mirror image*', 'misty step*', 'pass without trace', 'protection from poison', 'conjure animals', 'dispel magic', 'tidal wave|XGE', 'water breathing*', 'water walk*', 'charm monster|XGE', 'control water*', 'dominate beast', 'freedom of movement*', 'watery sphere|XGE', 'conjure elemental*', 'maelstrom|XGE', 'scrying*', 'tree stride', 'heal', 'plane shift']
# ['shape water|XGE', 'create or destroy water']
# ['Druidcraft', 'Resistance', 'Cure Wounds', 'Faerie Fire', 'Purify Food and Drink']
# ['Light', 'Mage Hand', 'Dimension Door', 'Disguise Self', 'Levitate', 'Mage Armor']
# ['dispel magic', 'aid', 'command', 'magic weapon', 'searing smite', 'shield of faith']
# ['animate dead', 'darkness', 'detect evil and good', 'detect magic', 'dispel evil and good', 'hallow', 'hold monster', 'suggestion', 'teleport', 'true seeing', 'symbol', 'wish']
# ['ensnaring strike', 'speak with animals', 'cordon of arrows', 'daylight', 'lesser restoration', 'nondetection']
# ['detect magic', 'identify', 'mage armor', "Rary's telepathic bond", 'clairvoyance', 'locate object', 'scrying', 'foresight', 'true seeing']
# ['ice storm', 'sleet storm', 'wall of ice', 'cone of cold', "otiluke's freezing sphere"]
# ['alter self', 'disguise self', 'levitate', 'major image', 'vicious mockery', 'bane', 'fear', 'hold monster', 'misty step', 'dimension door', 'seeming']
# ['alter self', 'blade ward', 'chill touch', 'disguise self', 'false life', 'invisibility', 'mage armor', 'silent image', 'armor of Agathys', 'cone of cold', 'darkness', 'fear', 'hallucinatory terrain', 'hold person', 'hypnotic pattern', 'major image', 'mirror image', 'mislead', 'sleet storm', 'dream', 'feeblemind', 'mass suggestion', 'project image']
# ['phantasmal killer', 'mirror image', 'mislead']
# ['mage armor', 'mirror image', 'shield', 'unseen servant', 'contingency', 'counterspell', 'dispel magic', 'fireball', 'simulacrum', 'scrying', 'clone', 'maze', 'meteor swarm', 'teleport']
# ['detect magic', 'detect thoughts', 'light', 'mage hand', 'magic missile', 'prestidigitation', 'shield', 'shocking grasp', 'banishment', 'counterspell', 'dominate person', 'fireball', 'lightning bolt', 'mirror image', 'misty step', 'chain lightning', 'finger of death', 'power word stun', 'teleport', 'wish']
# ['druidcraft', 'poison spray', 'shillelagh', 'entangle', 'locate creature', 'speak with animals', 'stoneskin', 'tree stride', 'water breathing', 'foresight', 'heal']
# ['guidance', 'light', 'aid', 'blur', 'cure wounds', 'shield', 'blink', 'elemental weapon', 'fire shield']
# ['entangle', 'barkskin', 'grasping vine', 'pass without trace']
# ['barkskin', 'druidcraft', 'poison spray', 'produce flame', 'shillelagh', 'animal messenger', 'commune with nature', 'entangle', 'speak with animals', 'heal', "heroes' feast", 'stoneskin']
# ["Melf's acid arrow", 'detect magic', 'detect thoughts', 'invisibility', 'magic missile', 'mage hand', 'mirror image', 'prestidigitation', 'ray of frost', 'shield', 'animate dead', 'dimension door', 'dispel magic', 'fireball', 'scrying', 'disintegrate', 'dominate monster', 'finger of death', 'power word kill', 'power word stun', 'time stop']
# ['clairvoyance', 'detect magic', 'fear', 'invisibility', 'spider climb', 'tongues', 'dispel magic', 'fog cloud']
# ['blade ward', 'eldritch blast', 'message', 'bane', 'charm person', 'daylight', 'faerie fire', 'fear', 'misty step', 'plane shift']
# ['darkness', 'detect evil and good', 'detect magic', 'dispel magic', 'geas', 'greater restoration', 'hallow', 'hold monster', 'locate creature', 'locate object', 'major image', 'resurrection', 'scrying', 'suggestion', 'wall of fire', 'meteor swarm', 'symbol', 'wish']
# ['lesser restoration', 'light', 'sanctuary', 'antilife shell', 'blade barrier', 'divine word', 'mass heal']
# ['astral projection', 'blight', 'charm person', 'detect evil and good', 'dispel magic', 'hallow', 'insect plague', 'telekinesis', 'teleport', 'wind walk', 'wish', 'dominate person', 'hypnotic pattern', 'plane shift']
# ['fire bolt', 'light', 'mage hand', 'prestidigitation', 'detect magic', 'mage armor', 'shield', 'suggestion', 'cone of cold', 'counterspell', 'fly', 'greater invisibility']
# ['mage hand', 'minor illusion', 'telekinesis', 'crown of madness', 'detect thoughts', 'dominate person', 'fear', 'fireball', 'phantasmal force', 'magic missile', 'shield', 'chain lightning', 'confusion', 'dominate monster', 'greater invisibility', 'hold monster', 'mass suggestion', 'prismatic spray', 'reverse gravity']
# ['fire bolt', 'light', 'mage hand', 'prestidigitation', 'counterspell', 'detect magic', 'mage armor', 'magic missile', 'misty step', 'suggestion', 'fly', 'greater invisibility', 'ice storm']
# ['resistance', 'sacred flame', 'thaumaturgy', 'animate dead', 'command', 'contagion', 'dispel magic', 'divination', 'harm', 'hold person', 'silence']
# ['clairvoyance', 'detect magic', 'fear', 'invisibility', 'spider climb', 'tongues', 'cloudkill', 'dispel magic', 'plane shift', "Tasha's hideous laughter"]
# ['crown of madness', 'fog cloud', 'invisibility']
# ['detect evil and good', 'detect magic', 'detect thoughts', 'dispel magic', 'fear', 'fly', 'mass suggestion', 'plane shift', 'finger of death', 'flame strike', 'power word kill', 'power word stun']
# ['detect magic', 'light', 'mage hand', 'disintegrate', 'counterspell', 'shield']
# ['dancing lights', 'light', 'sanctuary', 'thaumaturgy', 'cure wounds', 'death ward', 'lesser restoration', 'darkness', 'divine word', 'faerie fire', 'holy aura']
# ['bless', 'shield of faith', 'thunderous smite', 'aid', 'branding smite', 'lesser restoration', 'banishment', 'blinding smite', 'death ward', 'revivify']
# ['acid splash', 'light', 'mage armor', 'mage hand', 'prestidigitation', 'detect magic', "Tasha's hideous laughter", 'misty step', 'shield', 'suggestion', 'counterspell', 'fly', 'greater invisibility', 'hold person']
# ['acid splash', 'fire bolt', 'mage hand', 'animate dead', 'blight', 'false life', 'mage armor', 'ray of enfeeblement', 'ray of sickness', 'scrying', 'vampiric touch', "abi-dalzim's horrid wilting|XGE", 'finger of death']
# ['detect magic', 'mage hand', 'prestidigitation', 'dispel magic', 'hunger of Hadar', 'lightning bolt', 'arcane eye', 'dimension door', 'plane shift']
# ['druidcraft', 'fog cloud', 'guidance', 'goodberry', 'greater restoration', 'pass without trace', 'speak with plants']
# ['wall of force', 'command', 'detect evil and good']
# ['dancing lights', 'minor illusion', 'hallucinatory terrain', 'invisibility', 'major image', 'phantasmal force']
# ['light', 'thaumaturgy', 'bane', 'fear', 'freedom of movement', 'greater restoration', 'hold monster', 'revivify']
# ['daylight', 'lesser restoration']
# ['mage armor', 'prestidigitation', 'animal messenger', 'charm person', "Tasha's hideous laughter", 'bestow curse', 'dispel magic']
# ['prestidigitation', 'silent image']
# ['dancing lights', 'detect magic', 'prestidigitation', 'locate creature']
# ['blindness/deafness', 'bane', 'grease']
# ['friends', 'minor illusion', 'enthrall', "Nystul's magic aura"]
# ['dancing lights', 'detect magic', 'druidcraft', 'mage armor', 'faerie fire', 'gust of wind', 'mirror image']
# ['detect magic', 'prestidigitation', 'suggestion', 'major image', 'zone of truth']
# ['beast sense', 'druidcraft', 'entangle', 'animal messenger', 'stinking cloud']
# ['detect poison and disease', 'druidcraft', 'commune with nature', 'enlarge/reduce', 'speak with plants']
# ['detect magic', 'minor illusion', 'speak with dead', 'detect thoughts', 'dimension door', 'hold monster']
# ['druidcraft', 'guidance', 'purify food and drink', 'speak with plants', 'entangle', 'goodberry']
# ['light', 'mage hand', 'dimension door', 'telekinesis']
# ...
# ['command', 'create or destroy water', 'control water', 'darkness', 'water breathing', 'water walk', 'call lightning', "Evard's black tentacles"]
# ['charm person', 'command', 'comprehend languages', 'sanctuary', 'crown of madness', 'phantasmal force', 'see invisibility', 'clairvoyance', 'fear', 'meld into stone', 'confusion', 'stone shape', 'scrying', 'telekinesis', 'guidance', 'mage hand', 'vicious mockery', 'true strike', 'detect thoughts', 'levitate', 'dominate monster', 'plane shift']
# ['acid splash', 'mage hand', 'mending', 'ray of frost', 'shocking grasp', 'detect magic', 'identify', 'shield', 'witch bolt', 'darkness', 'detect thoughts', 'shatter', 'dispel magic', 'lightning bolt', 'sending', 'dimension door', "Evard's black tentacles", 'geas', 'scrying', 'chain lightning']
# ['chill touch', 'dancing lights', 'mage hand', 'mending', 'false life*', 'mage armor', 'ray of sickness*', 'blindness/deafness*', 'ray of enfeeblement*', 'web', 'animate dead*', 'bestow curse*', 'vampiric touch*', 'blight*', 'dimension door', 'stoneskin', "Bigby's hand", 'cloudkill', 'circle of death*']
# ['eldritch blast (range 300 ft., +4 bonus to each damage roll)', 'guidance', 'mage hand', 'minor illusion', 'prestidigitation', 'vicious mockery', 'arms of Hadar', 'counterspell', 'dimension door', 'fear', 'hold person', 'hunger of Hadar', 'invisibility', 'unseen servant']
# ['levitate', 'confusion', 'feeblemind', 'telekinesis']
# ['mage hand', "Tasha's hideous laughter", 'vicious mockery', 'confusion']
# ['guidance', 'mending', 'resistance', 'thaumaturgy', 'bane', 'cure wounds', 'guiding bolt', 'augury', 'warding bond', 'bestow curse', 'create food and water']
# ['guidance', 'mending', 'resistance', 'thaumaturgy', 'bane', 'detect magic', 'inflict wounds', 'protection from evil and good', 'blindness/deafness', 'silence']
# ['command', 'comprehend languages', 'detect thoughts', 'confusion', 'dominate monster']
# ['light', 'mending', 'prestidigitation', 'ray of frost', 'chromatic orb', 'expeditious retreat*', 'mage armor', 'alter self*', 'hold person', 'knock*', 'blink*', 'fireball', 'slow*', 'polymorph*', 'stoneskin', 'telekinesis*']
# ['detect thoughts', 'levitate', 'confusion', 'dominate monster', 'eyebite', 'feeblemind', 'mass suggestion', 'plane shift', 'project image', 'scrying', 'telekinesis']
# ['light', 'mending', 'sacred flame', 'spare the dying', 'divine favor', 'guiding bolt', 'healing word', 'shield of faith', 'lesser restoration', 'magic weapon', 'prayer of healing', 'silence', 'spiritual weapon', 'beacon of hope', "crusader's mantle", 'dispel magic', 'revivify', 'spirit guardians', 'water walk', 'banishment', 'freedom of movement', 'guardian of faith', 'stoneskin', 'flame strike', 'mass cure wounds', 'hold monster']
# ['disguise self', 'mage armor', 'silent image', 'speak with animals', 'conjure fey']
# ['alter self', 'false life', 'levitate', 'mage armor', 'silent image', 'feeblemind', 'finger of death', 'plane shift']
# ['detect magic', 'jump', 'levitate', 'mage armor', 'speak with dead', 'arcane gate', 'true seeing']
# ['detect magic', 'mage armor']
# ['animal friendship', 'divine word', 'darkness', 'entangle', 'fear', 'haste', 'suggestion', 'polymorph']
# ['animal friendship', 'suggestion']
# ['animal friendship', 'suggestion']
# ['animal friendship', 'suggestion']
# ['animal friendship', 'suggestion']
# ['animal friendship', 'suggestion']
# ['chill touch', 'detect thoughts', 'mage hand', 'zone of truth', 'charm person', 'hold person', 'compulsion', 'hold monster', 'sleep', "Tasha's hideous laughter"]
# ['arcane eye', 'calm emotions', 'detect magic', 'detect thoughts', 'dispel magic', 'sending', 'suggestion', 'mass suggestion', 'modify memory']
# ['detect magic', 'detect thoughts', 'dispel magic', 'sending', 'dimension door', 'fly', 'greater invisibility']
# ['detect magic', 'dispel magic', 'levitate', 'mage armor', 'mage hand', 'sending', "Otiluke's resilient sphere", 'telekinesis']
# ['plane shift', 'alter self', 'command', 'detect magic']
# ['detect magic', 'plane shift', 'create food and water', 'polymorph', 'remove curse']
# ['minor illusion', 'spare the dying', 'animal friendship', 'faerie fire', 'meld into stone', 'silence']
# ['detect magic', 'mage hand', 'plane shift', 'augury', 'polymorph']
# ['detect magic', 'disguise self', 'invisibility', 'light', 'mage hand', 'message', 'prestidigitation', "Tasha's hideous laughter", 'dispel magic', 'fly', 'polymorph', 'maze', 'telekinesis', 'teleport', 'wish']
# ['light', 'mage hand', 'prestidigitation', 'dominate beast', 'fly', 'mirror image', 'web']
# ['disguise self', 'friends', 'mage hand', 'minor illusion', 'bestow curse', 'faerie fire', 'speak with animals']
# ['light', 'spare the dying', 'death ward', 'command', 'create food and water', 'cure wounds', 'faerie fire', 'hold person', 'revivify']
# ['dancing lights', 'polymorph', 'ray of frost']
# ['fire bolt', 'invisibility', 'message']
# ['light', 'mage hand', 'prestidigitation', 'charm person', 'detect magic', 'sleep', 'banishment', 'dispel magic', 'fly', 'knock']
# ['color spray', 'mirror image', 'suggestion', 'major image', 'hallucinatory terrain', 'polymorph', 'dancing lights', 'mage hand', 'minor illusion']
# ['detect magic', 'druidcraft', 'speak with animals', 'awaken', 'plane shift', 'polymorph', 'remove curse', 'speak with plants']
# ['detect magic', 'disguise self', 'faerie fire', 'fly', 'hypnotic pattern', 'invisibility', 'mage armor']
# ['command', 'detect evil and good', 'protection from evil and good', 'lesser restoration', 'remove curse', 'zone of truth']
# ['dancing lights', 'message', 'prestidigitation']
# ['light', 'thaumaturgy', 'command', 'gaseous form', 'hold person', 'silence', 'speak with dead']
# ['friends', 'mage hand', 'mending', 'message', 'charm person', 'mage armor', 'magic missile', 'hold person', 'invisibility', 'suggestion', 'fireball', 'haste', 'tongues', 'confusion', 'stoneskin', 'hold monster']
# ['blade ward', 'light', 'mage hand', 'message', 'comprehend languages', 'identify', 'detect magic', 'mage armor', 'shield', 'detect thoughts', 'suggestion', 'clairvoyance', 'sending', 'locate creature', "Otiluke's resilient sphere"]
# ['mage hand', 'mending', 'minor illusion', 'vicious mockery', 'cure wounds', 'disguise self', 'sleep', 'crown of madness', 'invisibility', 'suggestion', 'nondetection', 'sending', 'tongues', 'compulsion', 'freedom of movement', 'polymorph', 'dominate person', 'greater restoration', "Otto's irresistible dance"]
# ['dancing lights', 'darkness', 'faerie fire', 'levitate']
# ['produce flame']
# ['fire bolt', 'mending', 'prestidigitation', 'burning hands', 'disguise self', 'shield']
# ['druidcraft', 'produce flame', 'shillelagh', 'entangle', 'longstrider', 'speak with animals', 'thunderwave', 'animal messenger', 'barkskin']
# ['fire bolt', 'mending', 'prestidigitation', 'burning hands', 'disguise self', 'shield']
# ['guidance', 'light', 'sacred flame', 'spare the dying', 'detect evil and good', 'healing word', 'sanctuary', 'shield of faith', 'calm emotions', 'prayer of healing', 'silence', 'protection from energy', 'remove curse', 'sending']
# ['light', 'mending', 'sacred flame', 'spare the dying', 'divine favor', 'guiding bolt', 'healing word', 'shield of faith', 'lesser restoration', 'magic weapon', 'hold person', 'silence', 'spiritual weapon', 'beacon of hope', "crusader's mantle", 'dispel magic', 'revivify', 'spirit guardians', 'water walk', 'banishment', 'freedom of movement', 'guardian of faith', 'stoneskin', 'flame strike', 'mass cure wounds', 'hold monster']
# ['thaumaturgy']
# ['dancing lights', 'darkness', 'faerie fire', 'levitate']
# ['fire bolt', 'light', 'mage hand', 'prestidigitation', 'detect magic', 'mage armor', 'magic missile', 'shield', 'misty step', 'suggestion', 'counterspell', 'fireball', 'sending', 'greater invisibility', 'ice storm', 'cone of cold']
# ['friends', 'mage hand', 'vicious mockery', 'charm person', 'healing word', 'heroism', 'sleep', 'thunderwave', 'invisibility', 'shatter']
# ['light', 'mage hand', 'minor illusion', 'prestidigitation', 'ray of frost', 'detect magic', 'disguise self', 'magic missile', 'shield', 'detect thoughts', 'invisibility', 'misty step', 'counterspell', 'fly', 'sending', 'tongues', 'banishment', 'greater invisibility', "Otiluke's resilient sphere", 'cone of cold', 'geas', "Rary's telepathic bond", 'globe of invulnerability', 'mass suggestion', 'prismatic spray', 'teleport', 'feeblemind', 'power word stun', 'time stop']
# ['thaumaturgy']
# ['fire bolt', 'light', 'mage hand', 'prestidigitation', 'detect magic', 'mage armor', 'magic missile', 'shield', 'misty step', 'suggestion', 'animate dead', 'fireball', 'fly', 'blight', 'ice storm', 'cone of cold']
# ['fire bolt', 'light', 'mage hand', 'prestidigitation', 'detect magic', 'mage armor', 'magic missile', 'shield', 'misty step', 'suggestion', 'counterspell', 'fireball', 'fly', 'greater invisibility', 'ice storm', 'cone of cold']
# ['fire bolt', 'light', 'mage hand', 'prestidigitation', 'shocking grasp', 'detect magic', 'mage armor', 'magic missile', 'shield', 'detect thoughts', 'mirror image', 'misty step', 'counterspell', 'lightning bolt', 'sending', 'fire shield', 'greater invisibility', 'polymorph', "Bigby's hand", 'scrying', 'wall of force', 'flesh to stone', 'globe of invulnerability', 'finger of death', 'simulacrum', 'feeblemind', 'mind blank', 'imprisonment', 'power word kill']
# ['fire bolt', 'light', 'mage hand', 'prestidigitation', 'shocking grasp', 'detect magic', 'mage armor', 'magic missile', 'shield', 'detect thoughts', 'mirror image', 'misty step', 'counterspell', 'lightning bolt', 'sending', 'fire shield', 'greater invisibility', 'polymorph', "Bigby's hand", 'scrying', 'wall of force']
# ['druidcraft', 'produce flame', 'shillelagh', 'entangle', 'longstrider', 'speak with animals', 'thunderwave', 'animal messenger', 'barkskin']
# ['fire bolt', 'mending', 'prestidigitation', 'burning hands', 'disguise self', 'shield']
# ['dancing lights', 'mage hand', 'mending', 'message', 'ray of frost', 'alarm', 'mage armor', 'magic missile', 'shield', 'arcane lock', 'invisibility', 'counterspell', 'dispel magic', 'fireball', 'banishment', 'stoneskin', 'cone of cold', 'wall of force', 'flesh to stone', 'globe of invulnerability', 'symbol', 'teleport']
# ['fire bolt', 'light', 'mage hand', 'prestidigitation', 'detect magic', 'mage armor', 'magic missile', 'shield', 'misty step', 'suggestion', 'counterspell', 'fireball', 'fly', 'greater invisibility', 'ice storm', 'cone of cold']
# ['fire bolt', 'light', 'mage hand', 'prestidigitation', 'detect magic', 'mage armor', 'magic missile', 'shield', 'misty step', 'suggestion', 'counterspell', 'fireball', 'fly', 'greater invisibility', 'ice storm', 'cone of cold']
# ['dancing lights', 'darkness', 'faerie fire', 'levitate']
# ['thaumaturgy']
# ['fire bolt', 'light', 'mage hand', 'message', 'prestidigitation', 'detect magic', 'identify', 'mage armor', 'thunderwave', 'invisibility', 'misty step', 'web', 'counterspell', 'fly', 'sending', 'banishment', 'fire shield', 'stoneskin', "Bigby's hand", 'geas', 'telekinesis', 'chain lightning', 'globe of invulnerability', 'forcecage', 'prismatic spray', 'antimagic field', 'power word stun', 'imprisonment']
# ['light', 'sacred flame', 'thaumaturgy', 'cure wounds', 'guiding bolt', 'sanctuary', 'lesser restoration', 'spiritual weapon', 'dispel magic', 'spirit guardians']
# ['guidance', 'light', 'mending', 'spare the dying', 'thaumaturgy', 'charm person', 'command', 'detect magic', 'disguise self', 'protection from evil and good', 'sanctuary', 'augury', 'lesser restoration', 'mirror image', 'pass without trace', 'spiritual weapon', 'blink', 'clairvoyance', 'dispel magic', 'magic circle', 'protection from energy', 'banishment', 'dimension door', 'divination', 'freedom of movement', 'polymorph', 'dominate person', 'flame strike', 'modify memory', 'insect plague', 'heal', 'divine word', 'earthquake']
# ['command', 'protection from evil and good', 'thunderous smite', 'branding smite', 'find steed', 'blinding smite', 'dispel magic']
# ['mage hand', 'prestidigitation', 'ray of frost', 'detect magic', 'magic missile', 'shield', 'thunderwave', 'detect thoughts', 'enlarge/reduce', "Melf's acid arrow", 'mirror image', 'counterspell', 'dispel magic', 'fireball', 'slow', 'blight', 'polymorph', 'animate objects', 'telekinesis', 'disintegrate', 'flesh to stone', 'reverse gravity', 'teleport', 'feeblemind', 'maze', 'true polymorph', 'alter self']
# ['alarm', 'detect magic', 'gaseous form', 'misty step', 'passwall', 'see invisibility']
# ['fire bolt', 'light', 'mage hand', 'prestidigitation', 'shocking grasp', 'detect magic', 'identify', 'mage armor*', 'magic missile', 'detect thoughts', 'mirror image', 'misty step', 'counterspell', 'fly', 'lightning bolt', 'polymorph', 'fire shield', 'stoneskin*', 'cone of cold', 'scrying', 'wall of force', 'globe of invulnerability', 'teleport', 'mind blank*', 'time stop']
# ['fire bolt', 'light', 'mage hand', 'prestidigitation', 'shocking grasp', 'detect magic', 'identify', 'mage armor*', 'magic missile', 'detect thoughts', 'mirror image', 'misty step', 'counterspell', 'fly', 'lightning bolt', 'phantasmal killer', 'fire shield', 'stoneskin*', 'cone of cold', 'scrying', 'wall of force', 'globe of invulnerability', 'teleport', 'mind blank*', 'time stop']
# ['command', 'compelled duel', 'searing smite', 'hold person', 'magic weapon', 'dispel magic', 'elemental weapon', 'locate creature', 'staggering smite', 'destructive wave (necrotic)']
# ['mage hand', 'prestidigitation', 'ray of frost', 'detect magic', 'magic missile', 'shield', 'thunderwave', 'detect thoughts', 'invisibility', "Melf's acid arrow", 'mirror image', 'animate dead', 'counterspell', 'dispel magic', 'fireball', 'blight', 'dimension door', 'cloudkill', 'scrying', 'disintegrate', 'globe of invulnerability', 'finger of death', 'forcecage', 'dominate monster', 'power word stun', 'power word kill']
# ['dancing lights', 'darkness', 'faerie fire']
# ['sacred flame', 'thaumaturgy', 'command', 'guiding bolt', 'shield of faith', 'hold person', 'silence', 'spiritual weapon', 'animate dead', 'dispel magic', 'stone shape', 'guardian of faith', 'contagion', 'insect plague', 'harm']
# ['dancing lights', 'fire bolt', 'light', 'mage hand', 'prestidigitation', 'mage armor', 'magic missile', 'shield', 'silent image', 'arcane lock', 'cloud of daggers', 'darkvision', 'knock', 'counterspell', 'dispel magic', 'fireball', 'confusion', 'hallucinatory terrain', 'polymorph', "Bigby's hand", 'geas', 'wall of force', 'chain lightning', 'globe of invulnerability', 'programmed illusion', 'finger of death', 'symbol', 'teleport', 'maze', 'mind blank', 'meteor swarm', 'wish', 'disguise self', 'invisibility', 'fly', 'lightning bolt']
# ['dancing lights', 'mage hand', "Melf's acid arrow", 'darkness', 'faerie fire', 'shield']
# ['guidance', 'mending', 'resistance', 'thaumaturgy', 'bane', 'command', 'inflict wounds', 'ray of sickness', 'blindness/deafness', 'ray of enfeeblement', 'spiritual weapon', 'animate dead', 'bestow curse', 'dispel magic', 'spirit guardians', 'blight', 'death ward', 'divination', 'antilife shell', 'destructive wave']
# ['dancing lights', 'mage hand', 'prestidigitation', 'ray of frost', 'shocking grasp', 'expeditious retreat', 'fog cloud', 'magic missile', 'shield', 'darkness', 'knock', 'see invisibility', 'spider climb', 'animate dead', 'counterspell', 'lightning bolt', 'greater invisibility', 'polymorph', 'animate objects', 'wall of force', 'create undead', 'flesh to stone', 'finger of death']
# ['mage hand', 'magic missile', 'shield', 'blur', 'flaming sphere', 'lightning bolt']
# ['fire bolt', 'mage hand', 'prestidigitation', 'detect magic', 'magic missile', 'shield', 'blur', 'detect thoughts', 'misty step', 'shatter', 'counterspell', 'dispel magic', 'fireball', 'haste', 'blight', 'greater invisibility', 'animate objects', "Bigby's hand", 'scrying', 'chain lightning', 'globe of invulnerability', 'finger of death', 'forcecage', 'incendiary cloud', 'power word stun', 'power word kill']

# %%
Monster_spells
# Out:
# [['detect magic',
#   'mage hand',
#   'prestidigitation',
#   'animate dead',
#   'dispel magic',
#   'speak with dead',
#   'finger of death',
#   'plane shift',
#   'project image'],
#  ['detect evil and good',
#   'mage armor',
#   'mage hand',
#   'protection from evil and good',
#   'remove curse',
#   'speak with dead',
#   'banishment',
#   'dispel evil and good'],
#  ['detect thoughts', 'augury'],
#  ['mage hand',
#   'message',
#   'vicious mockery',
#   'charm person',
#   'heroism',
#   'illusory script',
#   'sleep',
#   'unseen servant',
#   'cloud of daggers',
#   'invisibility'],
#  ['command',
#   'compelled duel',
#   'cure wounds',
#   'wrathful smite',
#   'aid',
#   'branding smite',
#   'lesser restoration',
#   'warding bond',
#   'zone of truth'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'detect magic',
#   'mage armor',
#   'distort value|AI*',
#   'gift of gab|AI*',
#   'suggestion',
#   'fast friends|AI*',
#   'lightning bolt',
#   'greater invisibility',
#   'cone of cold'],
#  ['fire bolt',
#   'friends',
#   'mage hand',
#   'minor illusion',
#   'prestidigitation',
#   'disguise self',
#   "Jim's magic missile|AI*",
#   'mage armor',
#   'invisibility',
#   "Jim's glowing coin|AI*",
#   'incite greed|AI*',
#   'fireball',
#   'conjure minor elementals',
#   'polymorph',
#   'mislead'],
#  ['dancing lights', 'disguise self', 'darkness', 'faerie fire'],
#  ['mage hand'],
#  ['guidance',
#   'sacred flame',
#   'spare the dying',
#   'thaumaturgy',
#   'bless',
#   'command',
#   'divine favor',
#   'shield of faith',
#   'enhance ability',
#   'hold person',
#   'magic weapon',
#   'silence',
#   'spiritual weapon',
#   'beacon of hope',
#   "crusader's mantle",
#   'dispel magic',
#   'mass healing word',
#   'spirit guardians',
#   'death ward',
#   'freedom of movement',
#   'locate creature',
#   'stoneskin',
#   'dispel evil and good',
#   'flame strike',
#   'hold monster',
#   'greater restoration',
#   'legend lore'],
#  ['acid splash',
#   'light',
#   'mage hand',
#   'poison spray',
#   'shocking grasp',
#   'detect magic',
#   'mage armor',
#   'magic missile',
#   'sleep',
#   'blindness/deafness',
#   'cloud of daggers',
#   'scorching ray'],
#  ['guidance',
#   'light',
#   'mending',
#   'sacred flame',
#   'bane',
#   'cure wounds',
#   'guiding bolt',
#   'hold person',
#   'spiritual weapon'],
#  ['light',
#   'sacred flame',
#   'thaumaturgy',
#   'cure wounds',
#   'guiding bolt',
#   'sanctuary',
#   'lesser restoration',
#   'spiritual weapon',
#   'dispel magic',
#   'spirit guardians'],
#  ['minor illusion',
#   'sacred flame',
#   'thaumaturgy',
#   'command',
#   'darkness',
#   'darkvision',
#   'pass without trace',
#   'silence'],
#  ['druidcraft',
#   'produce flame',
#   'thorn whip',
#   'cure wounds',
#   'entangle',
#   'thunderwave',
#   'flame blade',
#   'moonbeam',
#   'pass without trace',
#   'call lightning',
#   'dispel magic',
#   'plant growth',
#   'blight',
#   'freedom of movement'],
#  ['detect magic',
#   'comprehend languages',
#   'tongues',
#   'conjure elemental',
#   'invisibility',
#   'major image',
#   'plane shift',
#   'wall of fire'],
#  ['acid splash',
#   'mage hand',
#   'poison spray',
#   'prestidigitation',
#   'mage armor',
#   'magic missile',
#   'unseen servant*',
#   'cloud of daggers*',
#   'misty step*',
#   'web*',
#   'fireball',
#   'thunder step|XGE*',
#   "Evard's black tentacles*",
#   'stoneskin',
#   'cone of cold*',
#   'conjure elemental*'],
#  ['friends',
#   'mage hand',
#   'mending',
#   'message',
#   'charm person*',
#   'mage armor',
#   'magic missile',
#   'hold person*',
#   'invisibility',
#   'suggestion*',
#   'fireball',
#   'haste',
#   'tongues',
#   'arcane eye',
#   'phantasmal killer',
#   'hold monster*'],
#  ['banishment', 'detect thoughts', 'disguise self'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'minor illusion',
#   'shocking grasp',
#   'mage armor',
#   'magic missile',
#   'shield',
#   'thunderwave',
#   'invisibility*',
#   'mirror image*',
#   'phantasmal force*',
#   'counterspell',
#   'fly',
#   'lightning bolt',
#   'major image*',
#   'banishment',
#   'hallucinatory terrain*',
#   'phantasmal killer*',
#   'stoneskin',
#   'conjure elemental',
#   'mislead*',
#   'telekinesis',
#   'disintegrate',
#   'plane shift',
#   'maze'],
#  ['dancing lights', 'minor illusion', 'vicious mockery'],
#  ['detect evil and good',
#   'detect magic',
#   'detect thoughts',
#   'bless',
#   'create food and water',
#   'cure wounds',
#   'lesser restoration',
#   'protection from poison',
#   'sanctuary',
#   'shield',
#   'dream',
#   'greater restoration',
#   'scrying'],
#  ['calm emotions', 'detect magic', 'sending'],
#  ['revivify', 'speak with plants'],
#  ['fly', 'mislead', 'sending'],
#  ['teleport'],
#  ['cure wounds', 'hold person', 'divination', 'sending', 'word of recall'],
#  ['compulsion', 'fear'],
#  ['druidcraft', 'guidance', 'pass without trace', 'resistance'],
#  ['detect thoughts'],
#  ['light', 'mage hand', 'plane shift', 'telekinesis'],
#  ['light',
#   'mage hand',
#   'detect magic',
#   'invisibility',
#   'mage armor',
#   'tongues',
#   'contact other plane',
#   'plane shift',
#   'telekinesis'],
#  ['druidcraft',
#   'light',
#   'mage hand',
#   'invisibility',
#   'pass without trace',
#   'dominate monster',
#   'forcecage',
#   'plane shift',
#   'telekinesis'],
#  ['detect magic', 'light', 'dimension door', 'invisibility', 'mage armor'],
#  ['arms of Hadar',
#   'detect magic',
#   'magic missile',
#   "Tenser's floating disk",
#   'darkness',
#   'hold person',
#   'invisibility',
#   'spider climb',
#   'fear',
#   'hypnotic pattern',
#   'major image',
#   'stinking cloud'],
#  ['dimension door', 'invisibility'],
#  ['suggestion', 'disguise self', 'mage armor'],
#  ['disguise self', 'mage armor', 'dimension door', 'suggestion'],
#  ['suggestion', 'mage armor'],
#  ['light',
#   'mage hand',
#   'prestidigitation',
#   'dimension door',
#   'phantasmal force',
#   'mass suggestion',
#   'sending'],
#  ['friends', 'mage hand', 'prestidigitation', 'mirror image', 'spider climb'],
#  ['mage hand', 'invisibility'],
#  ['levitate', 'mage hand', 'freedom of movement', 'invisibility'],
#  ['mage hand',
#   'message',
#   'darkness',
#   'dimension door',
#   'fly',
#   'hypnotic pattern'],
#  ['wish'],
#  ['animate dead', 'branding smite', 'revivify', 'geas', 'raise dead'],
#  ['detect magic',
#   'fireball',
#   'dispel magic',
#   'hold monster',
#   'mirror image',
#   'mislead',
#   'raise dead',
#   'teleport',
#   'wall of fire',
#   'imprisonment',
#   'meteor swarm'],
#  ['guidance',
#   'sacred flame',
#   'thaumaturgy',
#   'bane',
#   'bless',
#   'cure wounds',
#   'guiding bolt (see "Actions" below)',
#   'blindness/deafness',
#   'hold person',
#   'silence',
#   'sending',
#   'spirit guardians'],
#  ['light',
#   'bless',
#   'cure wounds',
#   'protection from evil and good',
#   'banishment',
#   'heal',
#   'raise dead',
#   'shapechange',
#   'teleport'],
#  ['command',
#   'darkness',
#   'dispel evil and good',
#   'gate',
#   'harm',
#   'telekinesis',
#   'teleport',
#   'wind walk'],
#  ['chill touch',
#   'mending',
#   'resistance',
#   'sacred flame',
#   'spare the dying',
#   'thaumaturgy',
#   'cure wounds',
#   'detect evil and good',
#   'false life',
#   'inflict wounds',
#   'ray of sickness',
#   'blindness/deafness',
#   'gentle repose',
#   'hold person',
#   'ray of enfeeblement',
#   'spiritual weapon',
#   'animate dead',
#   'magic circle',
#   'speak with dead',
#   'spirit guardians',
#   'vampiric touch',
#   'banishment',
#   'blight',
#   'death ward',
#   'divination',
#   'locate creature',
#   'antilife shell',
#   'cloudkill',
#   'contagion',
#   'greater restoration',
#   'create undead',
#   'true seeing',
#   'divine word',
#   'regenerate'],
#  ['detect thoughts',
#   'disguise self',
#   'mage hand',
#   'minor illusion',
#   'charm person',
#   'detect magic',
#   'dispel magic',
#   'hellish rebuke',
#   'invisibility',
#   'major image',
#   'speak with dead',
#   'suggestion',
#   'banishment',
#   'demiplane',
#   'dominate person',
#   'fly',
#   'forcecage',
#   'geas',
#   'plane shift',
#   'true seeing'],
#  ['chill touch (see "Actions" below)',
#   'mage hand',
#   'message',
#   'prestidigitation',
#   'burning hands',
#   'detect magic',
#   'ray of sickness (see "Actions" below)',
#   'shield',
#   'darkness',
#   'misty step',
#   'scorching ray (see "Actions" below)',
#   'animate dead',
#   'fireball'],
#  ['charm person', 'disguise self', 'sanctuary'],
#  ['mage hand',
#   'message',
#   'prestidigitation',
#   'detect magic',
#   'protection from evil and good',
#   'ray of sickness (see "Actions" below)',
#   'shield',
#   'darkness',
#   'misty step'],
#  ['charm person',
#   "Tasha's hideous laughter",
#   'confusion',
#   'enthrall',
#   'suggestion',
#   'hallucinatory terrain',
#   "Otto's irresistible dance"],
#  ['guidance',
#   'sacred flame (see "Actions" below)',
#   'thaumaturgy',
#   'command',
#   'detect evil and good',
#   'sanctuary'],
#  ['detect magic',
#   'fog cloud',
#   'light',
#   'minor illusion',
#   'dream',
#   'gaseous form',
#   'major image'],
#  ['detect magic', 'fog cloud', 'light', 'gaseous form', 'telekinesis'],
#  ['detect magic', 'mage armor', 'speak with dead', "Tenser's floating disk"],
#  ['create or destroy water', 'detect magic', 'pass without trace'],
#  ['entangle',
#   'speak with animals',
#   'speak with plants',
#   'commune with nature',
#   'detect magic',
#   'disguise self'],
#  ['mage hand',
#   'minor illusion',
#   "Tasha's hideous laughter",
#   'detect magic',
#   'disguise self',
#   'dispel magic',
#   'polymorph'],
#  ['mage armor',
#   'mage hand',
#   'prestidigitation',
#   'chain lightning',
#   'cone of cold',
#   'fireball',
#   'fly',
#   'plane shift'],
#  ['detect magic',
#   'levitate',
#   'mage hand',
#   'prestidigitation',
#   'detect thoughts',
#   'suggestion',
#   'telekinesis'],
#  ['druidcraft', 'guidance', 'stone shape', 'wall of stone'],
#  ['meld into stone', 'stone shape', 'wall of stone'],
#  ['detect magic',
#   'detect thoughts',
#   'control water',
#   'control weather',
#   'dispel magic',
#   'plane shift',
#   'sending',
#   'time stop'],
#  ['detect magic',
#   'detect thoughts',
#   'mage hand',
#   'control water',
#   'control weather',
#   'sending'],
#  ['Guidance',
#   'Light',
#   'Thaumaturgy',
#   'Bless',
#   'Freedom of Movement',
#   'Greater Restoration',
#   'Plane Shift',
#   'Protection from Evil and Good',
#   'Revivify'],
#  ['Detect Magic', 'Heat Metal', 'Darkness', 'Dispel Magic', 'Hold Person'],
#  ['Prestidigitation',
#   'Speak with Animals',
#   'Bestow Curse',
#   'Command',
#   'Crown of Madness'],
#  ['Druidcraft',
#   'Pass without Trace',
#   'Goodberry',
#   'Lesser Restoration',
#   'Locate Creature',
#   'Move Earth',
#   'Transport via Plants'],
#  ['Bless',
#   'Guidance',
#   'Silent Image',
#   'Bane',
#   'Bestow Curse',
#   'Divination',
#   'Scrying'],
#  ['Dancing Lights',
#   'Mage Hand',
#   'Prestidigitation',
#   'Slow',
#   'Bestow Curse',
#   'Dispel Magic'],
#  ['Detect Magic',
#   'Mage Armor',
#   'Blight',
#   'Blindness/Deafness',
#   'Cloudkill',
#   'Contagion'],
#  ['Light',
#   'Spare the Dying',
#   'Thaumaturgy',
#   'Mass Cure Wounds',
#   'Blade Barrier',
#   'Divination',
#   'Greater Restoration'],
#  ['Detect Thoughts',
#   'Mage Hand',
#   'Thaumaturgy',
#   'Dimension Door',
#   'Mass Suggestion'],
#  ['Charm Person', 'Teleport', 'Dispel Magic', 'Fog Cloud'],
#  ['Mage Hand', 'Thaumaturgy', 'Dimension Door', 'Divination', 'Enthrall'],
#  ['Cure Wounds', 'Divination', 'Greater Restoration'],
#  ['Mage Hand', "Tasha's Hideous Laughter"],
#  ['Faerie Fire',
#   'Calm Emotions',
#   'Dispel Magic',
#   'Invisibility',
#   'Mass Cure Wounds',
#   'Revivify'],
#  ['Greater Restoration', 'Sending', 'Word of Recall'],
#  ['light',
#   'mage hand',
#   'prestidigitation',
#   'detect magic',
#   'dispel magic',
#   'faerie fire',
#   'hold monster',
#   'mind blank',
#   'teleport'],
#  ['fog cloud', 'control weather', 'telekinesis'],
#  ['sacred flame',
#   'thaumaturgy',
#   'command',
#   'guiding bolt',
#   'shield of faith',
#   'hold person',
#   'silence',
#   'spiritual weapon',
#   'animate dead',
#   'dispel magic',
#   'divination',
#   'guardian of faith',
#   'contagion',
#   'insect plague',
#   'harm'],
#  ['druidcraft',
#   'produce flame',
#   'shillelagh',
#   'entangle',
#   'longstrider',
#   'speak with animals',
#   'thunderwave',
#   'animal messenger',
#   'barkskin'],
#  ['druidcraft',
#   'detect magic',
#   'fog cloud',
#   'pass without trace',
#   'antilife shell',
#   'dispel magic',
#   'speak with plants',
#   'transport via plants',
#   'fire storm'],
#  ['light',
#   'mage hand',
#   'mending',
#   'prestidigitation',
#   'Shocking Grasp',
#   'comprehend languages',
#   'detect magic',
#   'dispel magic',
#   'identify',
#   'levitate',
#   'locate object',
#   'Shield',
#   "Tenser's Floating Disk",
#   'unseen servant',
#   'banishment',
#   'contact other plane',
#   "Drawmij's instant summons",
#   'legend lore',
#   'locate creature',
#   'planar binding',
#   'polymorph',
#   'protection from evil and good',
#   'scrying',
#   'sending',
#   'true seeing'],
#  ['dancing lights',
#   'mage hand',
#   'detect magic',
#   'detect thoughts',
#   'dispel magic',
#   'locate creature',
#   'dispel evil and good',
#   'wall of force'],
#  ['dispel magic', 'faerie fire', 'mirror image'],
#  ['light',
#   'sacred flame',
#   'thaumaturgy',
#   'command',
#   'inflict wounds',
#   'shield of faith',
#   'hold person',
#   'spiritual weapon'],
#  ['light',
#   'mage hand',
#   'mending',
#   'shocking grasp',
#   'comprehend languages',
#   'detect magic',
#   'identify',
#   'shield',
#   'dispel magic',
#   'levitate',
#   'locate object',
#   'see invisibility',
#   'sending',
#   'tongues',
#   'unseen servant'],
#  ['sacred flame',
#   'thaumaturgy',
#   'command',
#   'guiding bolt',
#   'shield of faith',
#   'hold person',
#   'silence',
#   'spiritual weapon',
#   'clairvoyance',
#   'dispel magic',
#   'divination',
#   'dimension door',
#   'contagion',
#   'scrying',
#   'harm'],
#  ['Bane',
#   'Bestow Curse',
#   'Command',
#   'Cure Wounds',
#   'Darkness',
#   'Lesser Restoration',
#   'Remove Curse',
#   'Antimagic Field',
#   'Earthquake',
#   'Flame Strike',
#   'Gate',
#   'Heal',
#   'Mass Heal',
#   'Wish'],
#  ['Animate Dead',
#   'Darkness',
#   'Detect Evil and Good',
#   'Detect Magic',
#   'Dispel Evil and Good',
#   'Hallow',
#   'Hold Monster',
#   'Suggestion',
#   'Teleport',
#   'True Seeing',
#   'Symbol',
#   'Wish'],
#  ['Detect Magic',
#   'Fireball',
#   'Dispel Magic',
#   'Hold Monster',
#   'Mirror Image',
#   'Mislead',
#   'Raise Dead',
#   'Teleport',
#   'Wall of Fire',
#   'Imprisonment',
#   'Meteor Swarm'],
#  ['Bestow Curse',
#   'Command',
#   'Darkness',
#   'Hold Monster',
#   'Major Image',
#   'Antilife Shell',
#   'Incendiary Cloud',
#   'Scrying',
#   'Weird'],
#  ['Detect Magic',
#   'Dispel Magic',
#   'Heroism',
#   'Magic Missile',
#   "Evard's Black Tentacles",
#   'Cone of Cold',
#   'Confusion',
#   'Dimension Door',
#   'Geas',
#   'Invisibility',
#   'Prismatic Wall',
#   'Slow'],
#  ['Bless',
#   'Detect Evil and Good',
#   'Foresight',
#   'Commune',
#   'Heal',
#   'Legend Lore',
#   'Raise Dead',
#   'Scrying'],
#  ['False Life',
#   'Gentle Repose',
#   'Lesser Restoration',
#   'Protection from Evil and Good',
#   'Speak with Dead',
#   'Antilife Shell',
#   'Blight',
#   'Death Ward',
#   'Dispel Evil and Good',
#   'Greater Restoration',
#   'Raise Dead',
#   'Regenerate',
#   'Revivify',
#   'Spiritual Weapon'],
#  ['Cone of Cold', 'Darkness', 'Ice Storm', 'Wall of Ice'],
#  ['Darkness',
#   'Detect Evil and Good',
#   'Detect Magic',
#   'Dispel Magic',
#   'Geas',
#   'Greater Restoration',
#   'Hallow',
#   'Hold Monster',
#   'Locate Creature',
#   'Locate Object',
#   'Major Image',
#   'Resurrection',
#   'Scrying',
#   'Suggestion',
#   'Wall of Fire',
#   'Meteor Swarm',
#   'Symbol',
#   'Wish'],
#  ['Aura of Purity',
#   'Compelled Duel',
#   "Crusader's Mantle",
#   'Death Ward',
#   'Dispel Evil and Good',
#   'Find Steed',
#   'Lesser Restoration',
#   'Remove Curse',
#   'Revivify',
#   'Shield of Faith'],
#  ['Resistance',
#   'Thaumaturgy',
#   'Animate Dead',
#   'Antimagic Field',
#   'Astral Projection',
#   'Blade Barrier',
#   'Command',
#   'Contagion',
#   'Dispel Magic',
#   'Divination',
#   'Etherealness',
#   'Fire Storm',
#   'Harm',
#   'Hold Person',
#   'Silence'],
#  ['Bane',
#   'Disguise Self',
#   'Dispel Magic',
#   'Mage Armor',
#   'Mirror Image',
#   'Thaumaturgy',
#   'Bestow Curse',
#   'Blindness/Deafness',
#   'Blink',
#   'Charm Person',
#   'Contagion',
#   'Dimension Door',
#   'Dominate Person',
#   'Hold Person',
#   'Pass Without Trace',
#   'Polymorph',
#   'Teleport'],
#  ['Alter Self',
#   'Detect Evil and Good',
#   'Fireball',
#   'Invisibility',
#   'Major Image',
#   'Wall of Fire',
#   'Blade Barrier',
#   'Dispel Evil and Good',
#   'Finger of Death'],
#  ['Arcane Eye',
#   'Detect Magic',
#   'Detect Thoughts',
#   'Fly',
#   'Light',
#   'Locate Object',
#   'Mage Armor',
#   'Mage Hand',
#   'Message',
#   'Prestidigitation',
#   'Cone of Cold',
#   'Foresight',
#   'Stoneskin',
#   "Rary's telepathic bond",
#   'True Seeing'],
#  ['acid splash',
#   'fire bolt',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'detect magic',
#   'magic missile',
#   'sleep',
#   'witch bolt',
#   'crown of madness',
#   'enlarge/reduce',
#   'misty step',
#   'dispel magic',
#   'fireball',
#   'lightning bolt',
#   'blight',
#   "Evard's black tentacles",
#   'polymorph',
#   'cloudkill',
#   'geas',
#   'scrying',
#   'programmed illusion',
#   'true seeing',
#   'finger of death',
#   'mirage arcane',
#   'power word stun'],
#  ['mage hand',
#   'prestidigitation',
#   'ray of frost',
#   'ray of sickness',
#   'sleep',
#   "Tasha's hideous laughter",
#   'alter self',
#   'invisibility'],
#  ['mage hand', 'prestidigitation', 'ray of frost'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'protection from evil and good',
#   'magic missile',
#   'shield',
#   'darkvision',
#   'knock',
#   'mirror image',
#   'clairvoyance',
#   'lightning bolt',
#   'magic circle',
#   'greater invisibility'],
#  ['counterspell', 'crown of madness', 'hypnotic pattern', 'telekinesis'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'detect magic',
#   'mage armor',
#   'magic missile',
#   'shield',
#   'misty step',
#   'suggestion',
#   'counterspell',
#   'fireball',
#   'fly',
#   'greater invisibility',
#   'ice storm',
#   'cone of cold'],
#  ['light',
#   'mending',
#   'thaumaturgy',
#   'command',
#   'purify food and drink',
#   'sanctuary',
#   'augury',
#   'gentle repose',
#   'hold person',
#   'animate dead',
#   'create food and water'],
#  ['light',
#   'mending',
#   'sacred flame',
#   'thaumaturgy',
#   'bane',
#   'command',
#   'detect evil and good',
#   'protection from evil and good',
#   'lesser restoration',
#   'protection from poison',
#   'spiritual weapon',
#   'create food and water',
#   'speak with dead',
#   'spirit guardians',
#   'divination',
#   'freedom of movement',
#   'guardian of faith',
#   'greater restoration',
#   'raise dead',
#   'find the path',
#   'harm',
#   'true seeing',
#   'fire storm',
#   'regenerate',
#   'earthquake'],
#  ['magic weapon', 'nondetection', 'misty step', 'phantom steed'],
#  ['guidance',
#   'light',
#   'mending',
#   'thaumaturgy',
#   'cure wounds',
#   'detect evil and good',
#   'protection from evil and good',
#   'sanctuary',
#   'augury',
#   'lesser restoration',
#   'protection from poison',
#   'magic circle',
#   'remove curse',
#   'speak with dead',
#   'death ward',
#   'freedom of movement',
#   'dispel evil and good'],
#  ['command',
#   'divine favor',
#   'thunderous smite',
#   'branding smite',
#   'magic weapon',
#   'blinding smite',
#   'dispel magic',
#   'staggering smite'],
#  ['friends',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'charm person',
#   'mage armor',
#   'shield',
#   'sleep',
#   'misty step',
#   'suggestion',
#   'bestow curse',
#   'phantom steed',
#   'vampiric touch',
#   'greater invisibility',
#   'stoneskin',
#   'dominate person'],
#  ['mage hand',
#   'prestidigitation',
#   'ray of frost',
#   'comprehend languages',
#   'fog cloud',
#   'sleep',
#   'detect thoughts',
#   'gust of wind',
#   'mirror image',
#   'animate dead',
#   'fireball',
#   'nondetection',
#   'blight',
#   'greater invisibility',
#   'polymorph',
#   'animate objects',
#   'scrying'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'shocking grasp',
#   'detect magic',
#   'mage armor',
#   'magic missile',
#   'shield',
#   'mirror image',
#   'misty step',
#   'web',
#   'counterspell',
#   'fly',
#   'lightning bolt',
#   "Mordenkainen's faithful hound",
#   'polymorph',
#   'stoneskin',
#   "Bigby's hand",
#   'cone of cold',
#   'scrying',
#   'true seeing',
#   "Mordenkainen's magnificent mansion",
#   'mind blank',
#   'time stop',
#   'disguise self',
#   'invisibility'],
#  ['guidance',
#   'light',
#   'lesser restoration',
#   'remove curse',
#   'water breathing'],
#  ['animal friendship', 'goodberry'],
#  ['animal friendship', 'goodberry', 'pass without trace'],
#  ['animal friendship',
#   'freedom of movement',
#   'goodberry',
#   'pass without trace',
#   'protection from energy'],
#  ['guidance', 'light', 'spare the dying', 'bless', 'cure wounds'],
#  ['guidance', 'light', 'spare the dying', 'revivify', 'bless', 'cure wounds'],
#  ['guidance', 'light', 'spare the dying', 'revivify', 'bless', 'cure wounds'],
#  ['minor illusion', 'mage armor', 'major image', 'phantasmal force'],
#  ['mage armor', 'mage hand', 'longstrider'],
#  ['mage armor', 'mage hand', 'longstrider', 'scrying', 'slow'],
#  ['mage hand',
#   'longstrider',
#   'scrying',
#   'slow',
#   'telekinesis',
#   'water breathing'],
#  ['alter self',
#   'light',
#   'mage hand',
#   'comprehend languages',
#   'mage armor',
#   'zone of truth'],
#  ['light',
#   'sacred flame',
#   'thaumaturgy',
#   'command',
#   'inflict wounds',
#   'shield of faith',
#   'hold person',
#   'spiritual weapon'],
#  ['detect magic', 'detect thoughts', 'identify', 'scrying'],
#  ['disguise self',
#   'detect thoughts',
#   'invisibility',
#   'dimension door',
#   'zone of truth'],
#  ['minor illusion', 'mage armor', 'major image', 'phantasmal force'],
#  ['light', 'mage hand', 'detect magic', 'levitate'],
#  ['dimension door', 'charm person', 'mage armor', 'sending'],
#  ['dancing lights',
#   'mage hand',
#   'comprehend languages',
#   'identify',
#   'mage armor'],
#  ['alter self',
#   'light',
#   'mage hand',
#   'comprehend languages',
#   'mage armor',
#   'zone of truth'],
#  ['chill touch', 'blindness/deafness', 'ray of sickness'],
#  ['dancing lights', 'darkness', 'faerie fire', 'levitate'],
#  ['guidance',
#   'light',
#   'resistance',
#   'sacred flame',
#   'spare the dying',
#   'bless',
#   'cure wounds',
#   'shield of faith',
#   'aid',
#   'lesser restoration',
#   'protection from energy',
#   'revivify',
#   'banishment',
#   'death ward',
#   'greater restoration',
#   'mass cure wounds',
#   'heal'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'minor illusion',
#   'shocking grasp',
#   'burning hands',
#   'shield',
#   'sleep',
#   'flaming sphere',
#   'invisibility',
#   'fireball',
#   'fly',
#   'polymorph',
#   'wall of fire',
#   'cone of cold',
#   'hold monster',
#   'chain lightning'],
#  ['thunderwave', 'augury', 'bless', 'lightning bolt', 'revivify'],
#  ['mage hand',
#   'prestidigitation',
#   'ray of frost (see "Actions" below)',
#   'detect magic',
#   'mage armor',
#   'magic missile (see "Actions" below)',
#   'shield'],
#  ['wall of stone', 'greater restoration'],
#  ['faerie fire',
#   'speak with animals',
#   'animal friendship',
#   'create food and water',
#   'revivify',
#   'awaken',
#   'pass without trace'],
#  ['thunderwave', 'light', 'ray of frost'],
#  ['invisibility',
#   'mage hand',
#   'dominate person',
#   'dimension door',
#   'disguise self',
#   'sending'],
#  ['enlarge/reduce', 'invisibility', 'stinking cloud', 'web'],
#  ['cure wounds', 'guidance', 'sacred flame'],
#  ['light',
#   'spare the dying',
#   'thaumaturgy',
#   'blade barrier',
#   'dispel magic',
#   'flame strike',
#   'lesser restoration',
#   'revivify'],
#  ['detect magic',
#   'light',
#   'prestidigitation',
#   'dimension door',
#   'mage armor',
#   'arcane eye',
#   'dominate person',
#   'wall of force'],
#  ['command', 'banishment', 'dispel magic', 'hold person'],
#  ['healing word', 'druidcraft', 'poison spray'],
#  ['dispel magic', 'wall of stone'],
#  ['counterspell',
#   'detect magic',
#   'dispel magic',
#   'see invisibility',
#   'antimagic field'],
#  ['hex'],
#  ['eldritch blast',
#   'false life',
#   'mage armor',
#   'mage hand',
#   'charm person',
#   'hex',
#   'hold person',
#   'invisibility'],
#  ['druidcraft',
#   'minor illusion',
#   'shocking grasp',
#   'cure wounds',
#   'fog cloud',
#   'thunderwave',
#   'hold person',
#   'mirror image',
#   'misty step',
#   'dispel magic',
#   'lightning bolt (see "Actions" below)',
#   'sleet storm'],
#  ['friends'],
#  ['light',
#   'sacred flame',
#   'spare the dying',
#   'command',
#   'cure wounds',
#   'guiding bolt',
#   'lesser restoration',
#   'spiritual weapon',
#   'dispel magic',
#   'revivify'],
#  ['eldritch blast',
#   'minor illusion',
#   'armor of Agathys',
#   'arms of Hadar',
#   'counterspell',
#   'crown of madness',
#   'invisibility',
#   'hunger of Hadar'],
#  ['witch bolt', 'bestow curse', 'fear', 'thunderwave'],
#  ['produce flame',
#   'resistance',
#   'thorn whip',
#   'entangle',
#   'fog cloud',
#   'blindness/deafness',
#   'spike growth',
#   'animate dead',
#   'conjure animals (reptiles only)'],
#  ['command',
#   'compelled duel',
#   'hellish rebuke',
#   'wrathful smite',
#   'branding smite',
#   'crown of madness',
#   'darkness',
#   'find steed',
#   'magic weapon'],
#  ['detect magic',
#   'disguise self',
#   'dream',
#   'hypnotic pattern',
#   'sleep',
#   'legend lore',
#   'scrying'],
#  ['charm person',
#   'dominate person',
#   'dream',
#   'detect thoughts',
#   'disguise self',
#   'suggestion'],
#  ['mage hand',
#   'vicious mockery',
#   'charm person',
#   'dissonant whispers',
#   'hex',
#   'hold person',
#   'mage armor'],
#  ['arcane eye', 'clairvoyance', 'confusion', 'dream', 'eyebite'],
#  ['chill touch (see "Actions" below)',
#   'fire bolt',
#   'mage hand',
#   'prestidigitation',
#   'ray of frost',
#   'magic missile',
#   'shield',
#   'sleep',
#   'blur',
#   'detect thoughts',
#   'mirror image',
#   'animate dead',
#   'counterspell',
#   'fireball',
#   'fly',
#   'lightning bolt',
#   'blight',
#   'confusion',
#   'polymorph',
#   'cloudkill',
#   'cone of cold',
#   'hold monster',
#   'scrying',
#   'chain lightning',
#   'circle of death',
#   'create undead',
#   'finger of death',
#   'forcecage',
#   'prismatic spray',
#   'incendiary cloud',
#   'maze',
#   'power word kill',
#   'time stop'],
#  ['mage hand', 'prestidigitation'],
#  ['chromatic orb',
#   'detect thoughts',
#   'disguise self',
#   'banishing smite',
#   'destructive wave',
#   'fly',
#   'mass suggestion',
#   'staggering smite',
#   'suggestion',
#   'true seeing'],
#  ['charm person',
#   'cure wounds',
#   'disguise self',
#   'thaumaturgy',
#   'commune',
#   'dominate person',
#   'insect plague',
#   'mass suggestion',
#   'raise dead'],
#  ['detect thoughts',
#   'dispel magic',
#   'spirit guardians',
#   'banishing smite',
#   'blinding smite',
#   'staggering smite'],
#  ['counterspell',
#   'detect magic',
#   'detect thoughts',
#   'dispel magic',
#   'eyebite',
#   'fireball',
#   'lightning bolt',
#   'shield',
#   'chain lightning',
#   'create undead',
#   'dream',
#   'hold monster',
#   'mass suggestion',
#   'scrying',
#   'foresight',
#   'gate',
#   'power word kill',
#   'teleport'],
#  ['fire bolt', 'chromatic orb'],
#  ['fire bolt (see "Actions" below)',
#   'mage hand',
#   'mending',
#   'prestidigitation',
#   'expeditious retreat',
#   'sanctuary',
#   'thunderwave',
#   'blur',
#   'heat metal',
#   'scorching ray',
#   'see invisibility',
#   'dispel magic',
#   'fly',
#   'haste',
#   'freedom of movement',
#   "Mordenkainen's faithful hound",
#   'animate objects',
#   'wall of force'],
#  ['charm person', 'fear'],
#  ['guidance',
#   'mending',
#   'sacred flame',
#   'spare the dying',
#   'thaumaturgy',
#   'bless',
#   'command',
#   'create or destroy water',
#   'augury',
#   'calm emotions',
#   'hold person',
#   'daylight',
#   'dispel magic',
#   'spirit guardians',
#   'banishment',
#   'divination',
#   'guardian of faith',
#   'dispel evil and good',
#   'flame strike (see "Actions" below)',
#   'scrying',
#   'forbiddance',
#   'planar ally',
#   'plane shift'],
#  ['detect thoughts', 'disguise self', 'shield'],
#  ['guidance', 'sacred flame', 'cure wounds'],
#  ['blink',
#   'control water',
#   'dispel magic',
#   'protection from evil and good',
#   'sending'],
#  ['dancing lights',
#   'guidance',
#   'command',
#   'divination',
#   'hypnotic pattern',
#   'lesser restoration'],
#  ['mage hand',
#   'minor illusion',
#   'detect thoughts',
#   'dispel magic',
#   'invisibility',
#   'major image'],
#  ['faerie fire', 'calm emotions', 'invisibility', 'revivify'],
#  ['dissonant whispers', 'hold monster', 'meld into stone', 'telekinesis'],
#  ['bane', 'control water', 'create or destroy water'],
#  ['protection from evil and good', "Tenser's floating disk", 'unseen servant'],
#  ['dispel magic', 'forcecage', 'plane shift', 'reverse gravity', 'time stop'],
#  ['blink',
#   'control water',
#   'dispel magic',
#   'freedom of movement',
#   'globe of invulnerability',
#   'plane shift',
#   'protection from evil and good',
#   'sending'],
#  ['dancing lights',
#   'guidance',
#   'command',
#   'divination',
#   'greater restoration',
#   'hypnotic pattern',
#   'invisibility'],
#  ['mage hand',
#   'minor illusion',
#   'detect thoughts',
#   'dispel magic',
#   'etherealness',
#   'major image',
#   'mislead'],
#  ['faerie fire', 'calm emotions', 'dispel magic', 'invisibility', 'revivify'],
#  ['dissonant whispers',
#   'hold monster',
#   'meld into stone',
#   'telekinesis',
#   'teleport'],
#  ['antilife shell', 'bane', 'control water', 'create or destroy water'],
#  ['dancing lights', 'guidance'],
#  ['dispel magic', 'forcecage', 'plane shift', 'reverse gravity', 'time stop'],
#  ['enlarge/reduce', 'invisibility', 'stinking cloud'],
#  ['invisibility', 'mage hand', 'dimension door', 'disguise self', 'sending'],
#  ['detect thoughts', 'invisibility', 'telekinesis'],
#  ['light',
#   'thaumaturgy',
#   'enhance ability',
#   'flame strike',
#   'mass cure wounds',
#   'revivify',
#   'tongues'],
#  ['dancing lights',
#   'calm emotions',
#   'charm person',
#   'command',
#   'comprehend languages'],
#  ["Bigby's hand", 'hypnotic pattern', 'telekinesis'],
#  ['mage hand', 'minor illusion'],
#  ['dispel magic', 'forcecage', 'plane shift', 'reverse gravity', 'time stop'],
#  ['alarm', "Tenser's floating disk"],
#  ['dispel magic', 'forcecage', 'plane shift', 'reverse gravity', 'time stop'],
#  ['bane'],
#  ['dispel magic', 'forcecage', 'plane shift', 'reverse gravity', 'time stop'],
#  ['blink', 'dispel magic', 'protection from evil and good', 'sending'],
#  ['dancing lights', 'guidance', 'hypnotic pattern', 'lesser restoration'],
#  ['mage hand',
#   'minor illusion',
#   'detect thoughts',
#   'invisibility',
#   'silent image'],
#  ['calm emotions', 'faerie fire'],
#  ['dissonant whispers', 'hold person', 'meld into stone'],
#  ['bane', 'create or destroy water'],
#  ['calm emotions', 'command', 'compelled duel'],
#  ['acid splash',
#   'light',
#   'mending',
#   'poison spray',
#   'shocking grasp',
#   'detect magic',
#   'grease',
#   'shield',
#   'alter self',
#   'darkvision',
#   'enlarge/reduce',
#   'hold person',
#   'counterspell',
#   'dispel magic',
#   'haste',
#   'protection from energy',
#   'confusion',
#   'conjure minor elementals',
#   'polymorph',
#   'cone of cold',
#   'creation',
#   'hold monster',
#   'move earth',
#   'wall of ice',
#   'prismatic spray',
#   'control weather'],
#  ['alter self',
#   'detect magic',
#   'eldritch blast',
#   'false life',
#   'levitate',
#   'mage armor',
#   'circle of death',
#   'enthrall',
#   'suggestion',
#   'hellish rebuke',
#   'hex',
#   'scorching ray'],
#  ['fire bolt', "Tasha's hideous laughter"],
#  ['druidcraft',
#   'dispel magic',
#   'entangle',
#   'plant growth',
#   'spike growth',
#   'moonbeam',
#   'grasping vine',
#   'wall of thorns'],
#  ['fireball', 'scorching ray', 'shield', 'thunderwave'],
#  ['enlarge/reduce',
#   'mage armor',
#   'scorching ray',
#   'counterspell',
#   'dispel magic',
#   'protection from energy'],
#  ['command',
#   'detect evil and good',
#   'raise dead',
#   'charm person',
#   'darkness',
#   'suggestion'],
#  ['acid splash',
#   'chill touch',
#   'mage hand',
#   'poison spray',
#   'prestidigitation',
#   'chromatic orb',
#   'magic missile',
#   'ray of sickness',
#   "Melf's acid arrow",
#   'ray of enfeeblement',
#   'spider climb',
#   'web',
#   'animate dead',
#   'bestow curse',
#   'fear',
#   'vampiric touch',
#   'blight',
#   "Evard's black tentacles",
#   'cloudkill',
#   'insect plague',
#   'circle of death',
#   'create undead',
#   'finger of death'],
#  ['druidcraft',
#   'produce flame',
#   'resistance',
#   'thorn whip',
#   'cure wounds',
#   'faerie fire',
#   'thunderwave',
#   'beast sense',
#   'flame blade',
#   'pass without trace',
#   'conjure animals',
#   'dispel magic',
#   'plant growth',
#   'dominate beast',
#   'freedom of movement',
#   'wall of fire',
#   'commune with nature',
#   'conjure elemental',
#   'scrying',
#   'transport via plants',
#   'wall of thorns'],
#  ['fire bolt',
#   'light',
#   'sacred flame',
#   'spare the dying',
#   'guiding bolt',
#   'healing word',
#   'heroism',
#   'shield of faith',
#   'lesser restoration',
#   'scorching ray',
#   'blinding smite',
#   "crusader's mantle",
#   'revivify',
#   'banishment',
#   'wall of fire',
#   'flame strike'],
#  ['compelled duel', 'guiding bolt', 'daylight', 'fireball'],
#  ['mage armor',
#   'scorching ray',
#   'banishment',
#   'cone of cold',
#   'dimension door',
#   'fireball',
#   'ice storm'],
#  ['mending',
#   'resistance',
#   'spare the dying',
#   'cure wounds',
#   'sanctuary',
#   'aid',
#   'lesser restoration'],
#  ['stoneskin', 'levitate', 'lightning bolt', 'thunderwave'],
#  ['poison spray',
#   'shillelagh',
#   'thorn whip',
#   'cure wounds',
#   'entangle',
#   'ray of sickness',
#   'pass without trace',
#   'ray of enfeeblement',
#   'spike growth',
#   'animate dead',
#   'dispel magic',
#   'plant growth',
#   'blight',
#   'giant insect'],
#  ['bless', 'conjure animals'],
#  ['imprisonment'],
#  ['acid splash',
#   'chill touch',
#   'mage hand',
#   'poison spray',
#   'prestidigitation',
#   'entangle',
#   'ray of sickness',
#   'sleep',
#   "Melf's acid arrow",
#   'ray of enfeeblement',
#   'spider climb',
#   'web',
#   'animate dead',
#   'plant growth',
#   'vampiric touch',
#   'blight',
#   'giant insect',
#   'grasping vine',
#   'cloudkill',
#   'insect plague',
#   'circle of death',
#   'create undead',
#   'finger of death',
#   'forcecage'],
#  ['chill touch',
#   'poison spray',
#   'ray of enfeeblement',
#   'ray of sickness',
#   'animate dead',
#   'blight',
#   'vampiric touch'],
#  ['fire bolt',
#   'friends',
#   'light',
#   'message',
#   'alarm',
#   'expeditious retreat',
#   'shield',
#   'arcane lock',
#   'detect thoughts',
#   'hold person',
#   'clairvoyance',
#   'dispel magic',
#   'slow',
#   'locate creature',
#   'stoneskin'],
#  ['detect thoughts',
#   'encode thoughts|GGR',
#   'freedom of movement',
#   'vicious mockery',
#   'blur',
#   'confusion',
#   'mirror image',
#   'modify memory',
#   "Rary's telepathic bond"],
#  ['charm person', 'crown of madness', 'dominate person'],
#  ['message',
#   'charm person',
#   'hold person',
#   'mirror image',
#   'sleep',
#   'gaseous form',
#   'major image'],
#  ['encode thoughts|GGR',
#   'friends',
#   'charm person',
#   'detect thoughts',
#   'mage armor',
#   'sleep',
#   'suggestion',
#   'dominate person',
#   'mass suggestion',
#   'modify memory'],
#  ['fire bolt',
#   'light',
#   'prestidigitation',
#   'ray of frost',
#   'shocking grasp',
#   'detect magic',
#   'magic missile',
#   'shield',
#   'thunderwave',
#   'unseen servant',
#   'blur',
#   'enlarge/reduce',
#   'flaming sphere',
#   'hold person',
#   'scorching ray',
#   'counterspell',
#   'fireball',
#   'lightning bolt',
#   'slow',
#   'confusion',
#   'dimension door',
#   'fabricate',
#   'conjure elemental',
#   'polymorph',
#   'wall of fire',
#   'wall of force',
#   'chain lightning',
#   'disintegrate',
#   'true seeing',
#   'project image',
#   'reverse gravity',
#   'teleport',
#   'control weather',
#   'maze',
#   'power word stun',
#   'prismatic wall'],
#  ['chill touch', 'sanctuary', 'spirit guardians'],
#  ['detect thoughts', 'mage armor', 'clairvoyance', 'locate object'],
#  ['hellish rebuke'],
#  ['dancing lights',
#   'minor illusion',
#   'vicious mockery',
#   'bane',
#   'dissonant whispers',
#   'silent image',
#   "Tasha's hideous laughter",
#   'thunderwave',
#   'crown of madness',
#   'enthrall',
#   'suggestion'],
#  ['blade ward',
#   'light',
#   'message',
#   'shocking grasp',
#   'guiding bolt',
#   'shield',
#   'thunderwave',
#   'witch bolt',
#   'blur',
#   'levitate',
#   'lightning bolt'],
#  ['clairvoyance',
#   'crown of madness',
#   'major image',
#   'suggestion',
#   'confusion',
#   'mass suggestion'],
#  ['friends',
#   'mage hand',
#   'message',
#   'command',
#   'ensnaring strike',
#   'shield',
#   'calm emotions',
#   'hold person',
#   'suggestion',
#   'clairvoyance',
#   'counterspell',
#   'dispel magic',
#   'banishment',
#   'divination',
#   'dominate person'],
#  ['charm person',
#   'disguise self',
#   'encode thoughts|GGR',
#   'blur',
#   'detect thoughts',
#   'gaseous form'],
#  ['dispel magic',
#   'druidcraft',
#   'bless',
#   'conjure animals',
#   'giant insect',
#   'moonbeam',
#   'plant growth',
#   'spike growth',
#   'suggestion',
#   'conjure fey',
#   'mass cure wounds'],
#  ['expeditious retreat', 'fog cloud', 'misty step'],
#  ['acid splash',
#   'druidcraft',
#   'ray of frost',
#   'shape water|XGE',
#   'color spray',
#   'expeditious retreat',
#   'fog cloud',
#   'shield',
#   'enlarge/reduce',
#   'gust of wind',
#   'counterspell',
#   'fly',
#   'slow',
#   'control water',
#   'ice storm',
#   'polymorph',
#   'conjure elemental',
#   'creation',
#   'move earth',
#   'wall of ice',
#   'prismatic spray',
#   'teleport',
#   'control weather',
#   'dominate monster'],
#  ['fog cloud'],
#  ['light',
#   'sacred flame',
#   'spare the dying',
#   'thaumaturgy',
#   'command',
#   'guiding bolt',
#   'purify food and drink',
#   'hold person',
#   'lesser restoration',
#   'silence',
#   'bestow curse',
#   'dispel magic'],
#  ['detect magic',
#   'detect thoughts',
#   'invisibility',
#   'fear',
#   'fireball',
#   'fly',
#   'cloudkill',
#   'etherealness'],
#  ['friends',
#   'mage hand',
#   'prestidigitation',
#   'ray of frost',
#   'disguise self',
#   'fog cloud',
#   'mage armor',
#   'witch bolt',
#   'gust of wind',
#   "Melf's acid arrow",
#   'misty step'],
#  ['chill touch',
#   'mage hand',
#   'minor illusion',
#   'prestidigitation',
#   'ray of frost',
#   'expeditious retreat',
#   'magic missile',
#   'shield',
#   'blur',
#   'hold person',
#   'sleet storm'],
#  ['guidance',
#   'mending',
#   'resistance',
#   'thaumaturgy',
#   'bless',
#   'detect magic',
#   'guiding bolt',
#   'hold person',
#   'spiritual weapon (trident)',
#   'bestow curse',
#   'fear',
#   'mass healing word',
#   'tongues',
#   'banishment'],
#  ['message', 'comprehend languages'],
#  ['dancing lights',
#   'minor illusion',
#   'ray of frost',
#   'charm person',
#   'color spray',
#   'magic missile',
#   'silent image',
#   'magic mouth',
#   'scorching ray'],
#  ['animal messenger',
#   'beast sense',
#   'speak with animals',
#   'cure wounds',
#   'entangle',
#   'faerie fire',
#   'thunderwave'],
#  ['friends', 'message', 'suggestion', 'charm person', 'disguise self'],
#  ['mage hand',
#   'minor illusion',
#   'prestidigitation',
#   'speak with dead',
#   'fog cloud',
#   'mage armor',
#   'magic missile',
#   'spider climb',
#   "Bigby's hand",
#   'major image'],
#  ['mage hand',
#   'message',
#   'prestidigitation',
#   'bestow curse',
#   "Bigby's hand",
#   'dimension door',
#   'mage armor',
#   "Otiluke's resilient sphere",
#   'thunderwave',
#   "Evard's black tentacles",
#   'finger of death',
#   'time stop'],
#  ['light',
#   'mage hand',
#   'shocking grasp',
#   'charm person',
#   'magic missile',
#   'hold person',
#   'misty step'],
#  ['minor illusion', 'Fire Bolt', 'grease', 'Burning Hands'],
#  ['guidance', 'Sacred Flame', 'cure wounds'],
#  ['mage hand',
#   'prestidigitation',
#   'ray of frost',
#   'shocking grasp',
#   'fog cloud',
#   'magic missile',
#   'shield',
#   'thunderwave',
#   'invisibility',
#   'misty step',
#   'scorching ray',
#   'counterspell',
#   'dispel magic',
#   'fireball'],
#  ['fog cloud', 'levitate'],
#  ['fire bolt',
#   'prestidigitation',
#   'shocking grasp',
#   'longstrider',
#   'magic missile',
#   'shield',
#   'thunderwave',
#   'magic weapon',
#   'misty step'],
#  ['light',
#   'sacred flame',
#   'thaumaturgy',
#   'command',
#   'cure wounds',
#   'healing word',
#   'sanctuary',
#   'calm emotions',
#   'hold person',
#   'spiritual weapon',
#   'mass healing word',
#   'spirit guardians'],
#  ['mage hand',
#   'minor illusion',
#   'prestidigitation',
#   'ray of frost',
#   'charm person',
#   'color spray',
#   'disguise self',
#   'longstrider'],
#  ['druidcraft',
#   'guidance',
#   'poison spray',
#   'cure wounds',
#   'entangle',
#   'healing word',
#   'thunderwave',
#   'barkskin',
#   'beast sense',
#   'spike growth',
#   'plant growth',
#   'water walk'],
#  ['fire bolt',
#   'minor illusion',
#   'prestidigitation',
#   'shocking grasp',
#   'chromatic orb',
#   'color spray',
#   'mage armor',
#   'magic missile',
#   'detect thoughts',
#   'mirror image',
#   'phantasmal force',
#   'counterspell',
#   'fireball',
#   'major image',
#   'confusion',
#   'greater invisibility',
#   'mislead',
#   'seeming',
#   'globe of invulnerability'],
#  ['guidance',
#   'resistance',
#   'thaumaturgy',
#   'command',
#   'cure wounds',
#   'healing word',
#   'inflict wounds',
#   'blindness/deafness',
#   'lesser restoration',
#   'spiritual weapon (spear)',
#   'dispel magic',
#   'mass healing word',
#   'sending',
#   'death ward',
#   'freedom of movement',
#   'insect plague'],
#  ['chromatic orb',
#   'detect magic',
#   'misty step',
#   'control weather',
#   'detect thoughts',
#   'ice storm'],
#  ['fire bolt (see "Actions" below)',
#   'mage hand',
#   'message',
#   'minor illusion',
#   'prestidigitation',
#   'detect magic',
#   'mage armor',
#   'magic missile',
#   'flaming sphere',
#   'knock',
#   'scorching ray',
#   'counterspell',
#   'fireball',
#   'fly',
#   'banishment',
#   'fire shield',
#   "Bigby's hand",
#   "Rary's telepathic bond"],
#  ['acid splash *',
#   'light',
#   'minor illusion',
#   'shocking grasp *',
#   'detect magic',
#   'disguise self',
#   'magic missile *',
#   'invisibility',
#   'levitate',
#   'phantasmal force',
#   'fireball',
#   'sending',
#   'slow',
#   'arcane eye',
#   'confusion',
#   'animate objects',
#   'Shocking Grasp',
#   'Acid Splash'],
#  ['acid splash*',
#   'light',
#   'minor illusion',
#   'shocking grasp*',
#   'detect magic',
#   'disguise self',
#   'magic missile*',
#   'invisibility',
#   'levitate',
#   'phantasmal force'],
#  ['druidcraft',
#   'guidance',
#   'resistance',
#   'animal friendship',
#   'fog cloud',
#   'speak with animals',
#   'animal messenger',
#   'moonbeam',
#   'pass without trace',
#   'conjure animals',
#   'sleet storm',
#   'wind wall',
#   'hallucinatory terrain',
#   'ice storm',
#   'awaken'],
#  ['detect thoughts', 'levitate', 'dominate monster', 'plane shift'],
#  ['levitate'],
#  ['druidcraft',
#   'mending',
#   'poison spray',
#   'detect magic',
#   'enlarge/reduce',
#   'faerie fire',
#   'invisibility',
#   'polymorph',
#   'stoneskin'],
#  ['mage hand',
#   'message',
#   'prestidigitation',
#   'ray of frost',
#   'detect magic',
#   'thunderwave',
#   'counterspell'],
#  ['light*',
#   'message*',
#   'prestidigitation',
#   'shocking grasp (see "Actions" below)',
#   'mage armor*',
#   'shield',
#   'sleep',
#   'arcane lock*',
#   'detect thoughts*',
#   'suggestion*',
#   'counterspell',
#   'lightning bolt*'],
#  ['misty step'],
#  ['fire bolt',
#   'mage hand',
#   'shocking grasp',
#   'silent image',
#   'chromatic orb',
#   'crown of madness',
#   'shield'],
#  ['chill touch (see "Actions" below)',
#   'light',
#   'mage hand',
#   'message',
#   'prestidigitation',
#   'comprehend languages',
#   'detect magic',
#   'ray of sickness',
#   "Tasha's hideous laughter",
#   'darkvision',
#   'hold person',
#   'ray of enfeeblement',
#   'animate dead',
#   "Leomund's tiny hut",
#   'vampiric touch (see "Actions" below)',
#   'arcane eye',
#   'blight'],
#  ['animal messenger',
#   'fog cloud',
#   'freedom of movement',
#   'pass without trace',
#   'silence',
#   'water walk'],
#  ['eldritch blast', 'mage hand', 'hold person', 'suggestion'],
#  ['ensnaring strike',
#   'hail of thorns',
#   "hunter's mark",
#   'locate animals or plants'],
#  ['light'],
#  ['dancing lights',
#   'light',
#   'message',
#   'shocking grasp',
#   'comprehend languages',
#   'cure wounds',
#   'grease',
#   'identify',
#   'detect thoughts',
#   'invisibility',
#   'heat metal',
#   'dispel magic',
#   'flame arrows|XGE',
#   'hypnotic pattern',
#   'fabricate',
#   'stone shape',
#   'stoneskin',
#   'creation'],
#  ['detect thoughts', 'command', 'hold person'],
#  ['light',
#   'mending',
#   'message',
#   'shocking grasp',
#   'alarm',
#   'cure wounds',
#   'identify',
#   'ray of sickness',
#   'invisibility',
#   "Melf's acid arrow",
#   'web',
#   'dispel magic',
#   'haste',
#   'stinking cloud',
#   'blight',
#   "Mordenkainen's faithful hound",
#   "Otiluke's resilient sphere",
#   'cloudkill'],
#  ['detect evil and good',
#   'cure wounds',
#   'lesser restoration',
#   'commune',
#   'dispel evil and good'],
#  ['control water', 'fog cloud', 'greater restoration'],
#  ['dancing lights',
#   'mage hand',
#   'mage armor',
#   'dispel magic',
#   'invisibility',
#   'polymorph'],
#  ['light',
#   'minor illusion',
#   'prestidigitation',
#   'detect magic',
#   'fog cloud',
#   'phantasmal force',
#   'shatter'],
#  ['project image', 'blindness/deafness', 'blur'],
#  ['arms of Hadar', 'charm person', 'mage armor'],
#  ['mage hand',
#   'prestidigitation',
#   'charm person',
#   'faerie fire',
#   'unseen servant'],
#  ['nondetection', 'dimension door', 'blindness/deafness', 'blur'],
#  ['detect thoughts',
#   'mage hand',
#   'zone of truth',
#   'charm person',
#   'command',
#   'hold person',
#   'compulsion',
#   'hold monster',
#   'sleep',
#   "Tasha's hideous laughter"],
#  ['blade ward',
#   'vicious mockery',
#   'charm person',
#   'detect magic',
#   'disguise self',
#   'identify',
#   "Tasha's hideous laughter"],
#  ['light'],
#  ['chill touch',
#   'eldritch blast',
#   'mage hand',
#   'darkness',
#   'hex',
#   'hypnotic pattern',
#   'misty step',
#   'phantasmal force',
#   'unseen servant'],
#  ['light',
#   'mage hand',
#   'shocking grasp',
#   'charm person',
#   'magic missile',
#   'hold person',
#   'misty step'],
#  ['dancing lights', 'darkness', 'faerie fire'],
#  ['mage hand', 'minor illusion', 'magic missile', 'unseen servant'],
#  ['guidance',
#   'mending',
#   'shape water|XGE',
#   'shillelagh',
#   'absorb elements|XGE',
#   'cure wounds',
#   'entangle',
#   'speak with animals',
#   'darkvision',
#   'hold person',
#   'lesser restoration',
#   'moonbeam',
#   'conjure animals',
#   'dispel magic',
#   'water breathing',
#   'charm monster|XGE',
#   'freedom of movement',
#   'greater restoration',
#   'mass cure wounds',
#   'conjure fey'],
#  ['frostbite|XGE',
#   'mending',
#   'resistance',
#   'shape water|XGE',
#   'thunderclap|XGE*',
#   'create or destroy water',
#   'charm person',
#   'cure wounds',
#   'thunderwave',
#   'darkvision',
#   'hold person',
#   'mirror image*',
#   'misty step*',
#   'pass without trace',
#   'protection from poison',
#   'conjure animals',
#   'dispel magic',
#   'tidal wave|XGE',
#   'water breathing*',
#   'water walk*',
#   'charm monster|XGE',
#   'control water*',
#   'dominate beast',
#   'freedom of movement*',
#   'watery sphere|XGE',
#   'conjure elemental*',
#   'maelstrom|XGE',
#   'scrying*',
#   'tree stride',
#   'heal',
#   'plane shift'],
#  ['shape water|XGE', 'create or destroy water'],
#  ['Druidcraft',
#   'Resistance',
#   'Cure Wounds',
#   'Faerie Fire',
#   'Purify Food and Drink'],
#  ['Light',
#   'Mage Hand',
#   'Dimension Door',
#   'Disguise Self',
#   'Levitate',
#   'Mage Armor'],
#  ['dispel magic',
#   'aid',
#   'command',
#   'magic weapon',
#   'searing smite',
#   'shield of faith'],
#  ['animate dead',
#   'darkness',
#   'detect evil and good',
#   'detect magic',
#   'dispel evil and good',
#   'hallow',
#   'hold monster',
#   'suggestion',
#   'teleport',
#   'true seeing',
#   'symbol',
#   'wish'],
#  ['ensnaring strike',
#   'speak with animals',
#   'cordon of arrows',
#   'daylight',
#   'lesser restoration',
#   'nondetection'],
#  ['detect magic',
#   'identify',
#   'mage armor',
#   "Rary's telepathic bond",
#   'clairvoyance',
#   'locate object',
#   'scrying',
#   'foresight',
#   'true seeing'],
#  ['ice storm',
#   'sleet storm',
#   'wall of ice',
#   'cone of cold',
#   "otiluke's freezing sphere"],
#  ['alter self',
#   'disguise self',
#   'levitate',
#   'major image',
#   'vicious mockery',
#   'bane',
#   'fear',
#   'hold monster',
#   'misty step',
#   'dimension door',
#   'seeming'],
#  ['alter self',
#   'blade ward',
#   'chill touch',
#   'disguise self',
#   'false life',
#   'invisibility',
#   'mage armor',
#   'silent image',
#   'armor of Agathys',
#   'cone of cold',
#   'darkness',
#   'fear',
#   'hallucinatory terrain',
#   'hold person',
#   'hypnotic pattern',
#   'major image',
#   'mirror image',
#   'mislead',
#   'sleet storm',
#   'dream',
#   'feeblemind',
#   'mass suggestion',
#   'project image'],
#  ['phantasmal killer', 'mirror image', 'mislead'],
#  ['mage armor',
#   'mirror image',
#   'shield',
#   'unseen servant',
#   'contingency',
#   'counterspell',
#   'dispel magic',
#   'fireball',
#   'simulacrum',
#   'scrying',
#   'clone',
#   'maze',
#   'meteor swarm',
#   'teleport'],
#  ['detect magic',
#   'detect thoughts',
#   'light',
#   'mage hand',
#   'magic missile',
#   'prestidigitation',
#   'shield',
#   'shocking grasp',
#   'banishment',
#   'counterspell',
#   'dominate person',
#   'fireball',
#   'lightning bolt',
#   'mirror image',
#   'misty step',
#   'chain lightning',
#   'finger of death',
#   'power word stun',
#   'teleport',
#   'wish'],
#  ['druidcraft',
#   'poison spray',
#   'shillelagh',
#   'entangle',
#   'locate creature',
#   'speak with animals',
#   'stoneskin',
#   'tree stride',
#   'water breathing',
#   'foresight',
#   'heal'],
#  ['guidance',
#   'light',
#   'aid',
#   'blur',
#   'cure wounds',
#   'shield',
#   'blink',
#   'elemental weapon',
#   'fire shield'],
#  ['entangle', 'barkskin', 'grasping vine', 'pass without trace'],
#  ['barkskin',
#   'druidcraft',
#   'poison spray',
#   'produce flame',
#   'shillelagh',
#   'animal messenger',
#   'commune with nature',
#   'entangle',
#   'speak with animals',
#   'heal',
#   "heroes' feast",
# ...
#   'thaumaturgy',
#   'bane',
#   'detect magic',
#   'inflict wounds',
#   'protection from evil and good',
#   'blindness/deafness',
#   'silence'],
#  ['command',
#   'comprehend languages',
#   'detect thoughts',
#   'confusion',
#   'dominate monster'],
#  ['light',
#   'mending',
#   'prestidigitation',
#   'ray of frost',
#   'chromatic orb',
#   'expeditious retreat*',
#   'mage armor',
#   'alter self*',
#   'hold person',
#   'knock*',
#   'blink*',
#   'fireball',
#   'slow*',
#   'polymorph*',
#   'stoneskin',
#   'telekinesis*'],
#  ['detect thoughts',
#   'levitate',
#   'confusion',
#   'dominate monster',
#   'eyebite',
#   'feeblemind',
#   'mass suggestion',
#   'plane shift',
#   'project image',
#   'scrying',
#   'telekinesis'],
#  ['light',
#   'mending',
#   'sacred flame',
#   'spare the dying',
#   'divine favor',
#   'guiding bolt',
#   'healing word',
#   'shield of faith',
#   'lesser restoration',
#   'magic weapon',
#   'prayer of healing',
#   'silence',
#   'spiritual weapon',
#   'beacon of hope',
#   "crusader's mantle",
#   'dispel magic',
#   'revivify',
#   'spirit guardians',
#   'water walk',
#   'banishment',
#   'freedom of movement',
#   'guardian of faith',
#   'stoneskin',
#   'flame strike',
#   'mass cure wounds',
#   'hold monster'],
#  ['disguise self',
#   'mage armor',
#   'silent image',
#   'speak with animals',
#   'conjure fey'],
#  ['alter self',
#   'false life',
#   'levitate',
#   'mage armor',
#   'silent image',
#   'feeblemind',
#   'finger of death',
#   'plane shift'],
#  ['detect magic',
#   'jump',
#   'levitate',
#   'mage armor',
#   'speak with dead',
#   'arcane gate',
#   'true seeing'],
#  ['detect magic', 'mage armor'],
#  ['animal friendship',
#   'divine word',
#   'darkness',
#   'entangle',
#   'fear',
#   'haste',
#   'suggestion',
#   'polymorph'],
#  ['animal friendship', 'suggestion'],
#  ['animal friendship', 'suggestion'],
#  ['animal friendship', 'suggestion'],
#  ['animal friendship', 'suggestion'],
#  ['animal friendship', 'suggestion'],
#  ['chill touch',
#   'detect thoughts',
#   'mage hand',
#   'zone of truth',
#   'charm person',
#   'hold person',
#   'compulsion',
#   'hold monster',
#   'sleep',
#   "Tasha's hideous laughter"],
#  ['arcane eye',
#   'calm emotions',
#   'detect magic',
#   'detect thoughts',
#   'dispel magic',
#   'sending',
#   'suggestion',
#   'mass suggestion',
#   'modify memory'],
#  ['detect magic',
#   'detect thoughts',
#   'dispel magic',
#   'sending',
#   'dimension door',
#   'fly',
#   'greater invisibility'],
#  ['detect magic',
#   'dispel magic',
#   'levitate',
#   'mage armor',
#   'mage hand',
#   'sending',
#   "Otiluke's resilient sphere",
#   'telekinesis'],
#  ['plane shift', 'alter self', 'command', 'detect magic'],
#  ['detect magic',
#   'plane shift',
#   'create food and water',
#   'polymorph',
#   'remove curse'],
#  ['minor illusion',
#   'spare the dying',
#   'animal friendship',
#   'faerie fire',
#   'meld into stone',
#   'silence'],
#  ['detect magic', 'mage hand', 'plane shift', 'augury', 'polymorph'],
#  ['detect magic',
#   'disguise self',
#   'invisibility',
#   'light',
#   'mage hand',
#   'message',
#   'prestidigitation',
#   "Tasha's hideous laughter",
#   'dispel magic',
#   'fly',
#   'polymorph',
#   'maze',
#   'telekinesis',
#   'teleport',
#   'wish'],
#  ['light',
#   'mage hand',
#   'prestidigitation',
#   'dominate beast',
#   'fly',
#   'mirror image',
#   'web'],
#  ['disguise self',
#   'friends',
#   'mage hand',
#   'minor illusion',
#   'bestow curse',
#   'faerie fire',
#   'speak with animals'],
#  ['light',
#   'spare the dying',
#   'death ward',
#   'command',
#   'create food and water',
#   'cure wounds',
#   'faerie fire',
#   'hold person',
#   'revivify'],
#  ['dancing lights', 'polymorph', 'ray of frost'],
#  ['fire bolt', 'invisibility', 'message'],
#  ['light',
#   'mage hand',
#   'prestidigitation',
#   'charm person',
#   'detect magic',
#   'sleep',
#   'banishment',
#   'dispel magic',
#   'fly',
#   'knock'],
#  ['color spray',
#   'mirror image',
#   'suggestion',
#   'major image',
#   'hallucinatory terrain',
#   'polymorph',
#   'dancing lights',
#   'mage hand',
#   'minor illusion'],
#  ['detect magic',
#   'druidcraft',
#   'speak with animals',
#   'awaken',
#   'plane shift',
#   'polymorph',
#   'remove curse',
#   'speak with plants'],
#  ['detect magic',
#   'disguise self',
#   'faerie fire',
#   'fly',
#   'hypnotic pattern',
#   'invisibility',
#   'mage armor'],
#  ['command',
#   'detect evil and good',
#   'protection from evil and good',
#   'lesser restoration',
#   'remove curse',
#   'zone of truth'],
#  ['dancing lights', 'message', 'prestidigitation'],
#  ['light',
#   'thaumaturgy',
#   'command',
#   'gaseous form',
#   'hold person',
#   'silence',
#   'speak with dead'],
#  ['friends',
#   'mage hand',
#   'mending',
#   'message',
#   'charm person',
#   'mage armor',
#   'magic missile',
#   'hold person',
#   'invisibility',
#   'suggestion',
#   'fireball',
#   'haste',
#   'tongues',
#   'confusion',
#   'stoneskin',
#   'hold monster'],
#  ['blade ward',
#   'light',
#   'mage hand',
#   'message',
#   'comprehend languages',
#   'identify',
#   'detect magic',
#   'mage armor',
#   'shield',
#   'detect thoughts',
#   'suggestion',
#   'clairvoyance',
#   'sending',
#   'locate creature',
#   "Otiluke's resilient sphere"],
#  ['mage hand',
#   'mending',
#   'minor illusion',
#   'vicious mockery',
#   'cure wounds',
#   'disguise self',
#   'sleep',
#   'crown of madness',
#   'invisibility',
#   'suggestion',
#   'nondetection',
#   'sending',
#   'tongues',
#   'compulsion',
#   'freedom of movement',
#   'polymorph',
#   'dominate person',
#   'greater restoration',
#   "Otto's irresistible dance"],
#  ['dancing lights', 'darkness', 'faerie fire', 'levitate'],
#  ['produce flame'],
#  ['fire bolt',
#   'mending',
#   'prestidigitation',
#   'burning hands',
#   'disguise self',
#   'shield'],
#  ['druidcraft',
#   'produce flame',
#   'shillelagh',
#   'entangle',
#   'longstrider',
#   'speak with animals',
#   'thunderwave',
#   'animal messenger',
#   'barkskin'],
#  ['fire bolt',
#   'mending',
#   'prestidigitation',
#   'burning hands',
#   'disguise self',
#   'shield'],
#  ['guidance',
#   'light',
#   'sacred flame',
#   'spare the dying',
#   'detect evil and good',
#   'healing word',
#   'sanctuary',
#   'shield of faith',
#   'calm emotions',
#   'prayer of healing',
#   'silence',
#   'protection from energy',
#   'remove curse',
#   'sending'],
#  ['light',
#   'mending',
#   'sacred flame',
#   'spare the dying',
#   'divine favor',
#   'guiding bolt',
#   'healing word',
#   'shield of faith',
#   'lesser restoration',
#   'magic weapon',
#   'hold person',
#   'silence',
#   'spiritual weapon',
#   'beacon of hope',
#   "crusader's mantle",
#   'dispel magic',
#   'revivify',
#   'spirit guardians',
#   'water walk',
#   'banishment',
#   'freedom of movement',
#   'guardian of faith',
#   'stoneskin',
#   'flame strike',
#   'mass cure wounds',
#   'hold monster'],
#  ['thaumaturgy'],
#  ['dancing lights', 'darkness', 'faerie fire', 'levitate'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'detect magic',
#   'mage armor',
#   'magic missile',
#   'shield',
#   'misty step',
#   'suggestion',
#   'counterspell',
#   'fireball',
#   'sending',
#   'greater invisibility',
#   'ice storm',
#   'cone of cold'],
#  ['friends',
#   'mage hand',
#   'vicious mockery',
#   'charm person',
#   'healing word',
#   'heroism',
#   'sleep',
#   'thunderwave',
#   'invisibility',
#   'shatter'],
#  ['light',
#   'mage hand',
#   'minor illusion',
#   'prestidigitation',
#   'ray of frost',
#   'detect magic',
#   'disguise self',
#   'magic missile',
#   'shield',
#   'detect thoughts',
#   'invisibility',
#   'misty step',
#   'counterspell',
#   'fly',
#   'sending',
#   'tongues',
#   'banishment',
#   'greater invisibility',
#   "Otiluke's resilient sphere",
#   'cone of cold',
#   'geas',
#   "Rary's telepathic bond",
#   'globe of invulnerability',
#   'mass suggestion',
#   'prismatic spray',
#   'teleport',
#   'feeblemind',
#   'power word stun',
#   'time stop'],
#  ['thaumaturgy'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'detect magic',
#   'mage armor',
#   'magic missile',
#   'shield',
#   'misty step',
#   'suggestion',
#   'animate dead',
#   'fireball',
#   'fly',
#   'blight',
#   'ice storm',
#   'cone of cold'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'detect magic',
#   'mage armor',
#   'magic missile',
#   'shield',
#   'misty step',
#   'suggestion',
#   'counterspell',
#   'fireball',
#   'fly',
#   'greater invisibility',
#   'ice storm',
#   'cone of cold'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'shocking grasp',
#   'detect magic',
#   'mage armor',
#   'magic missile',
#   'shield',
#   'detect thoughts',
#   'mirror image',
#   'misty step',
#   'counterspell',
#   'lightning bolt',
#   'sending',
#   'fire shield',
#   'greater invisibility',
#   'polymorph',
#   "Bigby's hand",
#   'scrying',
#   'wall of force',
#   'flesh to stone',
#   'globe of invulnerability',
#   'finger of death',
#   'simulacrum',
#   'feeblemind',
#   'mind blank',
#   'imprisonment',
#   'power word kill'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'shocking grasp',
#   'detect magic',
#   'mage armor',
#   'magic missile',
#   'shield',
#   'detect thoughts',
#   'mirror image',
#   'misty step',
#   'counterspell',
#   'lightning bolt',
#   'sending',
#   'fire shield',
#   'greater invisibility',
#   'polymorph',
#   "Bigby's hand",
#   'scrying',
#   'wall of force'],
#  ['druidcraft',
#   'produce flame',
#   'shillelagh',
#   'entangle',
#   'longstrider',
#   'speak with animals',
#   'thunderwave',
#   'animal messenger',
#   'barkskin'],
#  ['fire bolt',
#   'mending',
#   'prestidigitation',
#   'burning hands',
#   'disguise self',
#   'shield'],
#  ['dancing lights',
#   'mage hand',
#   'mending',
#   'message',
#   'ray of frost',
#   'alarm',
#   'mage armor',
#   'magic missile',
#   'shield',
#   'arcane lock',
#   'invisibility',
#   'counterspell',
#   'dispel magic',
#   'fireball',
#   'banishment',
#   'stoneskin',
#   'cone of cold',
#   'wall of force',
#   'flesh to stone',
#   'globe of invulnerability',
#   'symbol',
#   'teleport'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'detect magic',
#   'mage armor',
#   'magic missile',
#   'shield',
#   'misty step',
#   'suggestion',
#   'counterspell',
#   'fireball',
#   'fly',
#   'greater invisibility',
#   'ice storm',
#   'cone of cold'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'detect magic',
#   'mage armor',
#   'magic missile',
#   'shield',
#   'misty step',
#   'suggestion',
#   'counterspell',
#   'fireball',
#   'fly',
#   'greater invisibility',
#   'ice storm',
#   'cone of cold'],
#  ['dancing lights', 'darkness', 'faerie fire', 'levitate'],
#  ['thaumaturgy'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'message',
#   'prestidigitation',
#   'detect magic',
#   'identify',
#   'mage armor',
#   'thunderwave',
#   'invisibility',
#   'misty step',
#   'web',
#   'counterspell',
#   'fly',
#   'sending',
#   'banishment',
#   'fire shield',
#   'stoneskin',
#   "Bigby's hand",
#   'geas',
#   'telekinesis',
#   'chain lightning',
#   'globe of invulnerability',
#   'forcecage',
#   'prismatic spray',
#   'antimagic field',
#   'power word stun',
#   'imprisonment'],
#  ['light',
#   'sacred flame',
#   'thaumaturgy',
#   'cure wounds',
#   'guiding bolt',
#   'sanctuary',
#   'lesser restoration',
#   'spiritual weapon',
#   'dispel magic',
#   'spirit guardians'],
#  ['guidance',
#   'light',
#   'mending',
#   'spare the dying',
#   'thaumaturgy',
#   'charm person',
#   'command',
#   'detect magic',
#   'disguise self',
#   'protection from evil and good',
#   'sanctuary',
#   'augury',
#   'lesser restoration',
#   'mirror image',
#   'pass without trace',
#   'spiritual weapon',
#   'blink',
#   'clairvoyance',
#   'dispel magic',
#   'magic circle',
#   'protection from energy',
#   'banishment',
#   'dimension door',
#   'divination',
#   'freedom of movement',
#   'polymorph',
#   'dominate person',
#   'flame strike',
#   'modify memory',
#   'insect plague',
#   'heal',
#   'divine word',
#   'earthquake'],
#  ['command',
#   'protection from evil and good',
#   'thunderous smite',
#   'branding smite',
#   'find steed',
#   'blinding smite',
#   'dispel magic'],
#  ['mage hand',
#   'prestidigitation',
#   'ray of frost',
#   'detect magic',
#   'magic missile',
#   'shield',
#   'thunderwave',
#   'detect thoughts',
#   'enlarge/reduce',
#   "Melf's acid arrow",
#   'mirror image',
#   'counterspell',
#   'dispel magic',
#   'fireball',
#   'slow',
#   'blight',
#   'polymorph',
#   'animate objects',
#   'telekinesis',
#   'disintegrate',
#   'flesh to stone',
#   'reverse gravity',
#   'teleport',
#   'feeblemind',
#   'maze',
#   'true polymorph',
#   'alter self'],
#  ['alarm',
#   'detect magic',
#   'gaseous form',
#   'misty step',
#   'passwall',
#   'see invisibility'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'shocking grasp',
#   'detect magic',
#   'identify',
#   'mage armor*',
#   'magic missile',
#   'detect thoughts',
#   'mirror image',
#   'misty step',
#   'counterspell',
#   'fly',
#   'lightning bolt',
#   'polymorph',
#   'fire shield',
#   'stoneskin*',
#   'cone of cold',
#   'scrying',
#   'wall of force',
#   'globe of invulnerability',
#   'teleport',
#   'mind blank*',
#   'time stop'],
#  ['fire bolt',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'shocking grasp',
#   'detect magic',
#   'identify',
#   'mage armor*',
#   'magic missile',
#   'detect thoughts',
#   'mirror image',
#   'misty step',
#   'counterspell',
#   'fly',
#   'lightning bolt',
#   'phantasmal killer',
#   'fire shield',
#   'stoneskin*',
#   'cone of cold',
#   'scrying',
#   'wall of force',
#   'globe of invulnerability',
#   'teleport',
#   'mind blank*',
#   'time stop'],
#  ['command',
#   'compelled duel',
#   'searing smite',
#   'hold person',
#   'magic weapon',
#   'dispel magic',
#   'elemental weapon',
#   'locate creature',
#   'staggering smite',
#   'destructive wave (necrotic)'],
#  ['mage hand',
#   'prestidigitation',
#   'ray of frost',
#   'detect magic',
#   'magic missile',
#   'shield',
#   'thunderwave',
#   'detect thoughts',
#   'invisibility',
#   "Melf's acid arrow",
#   'mirror image',
#   'animate dead',
#   'counterspell',
#   'dispel magic',
#   'fireball',
#   'blight',
#   'dimension door',
#   'cloudkill',
#   'scrying',
#   'disintegrate',
#   'globe of invulnerability',
#   'finger of death',
#   'forcecage',
#   'dominate monster',
#   'power word stun',
#   'power word kill'],
#  ['dancing lights', 'darkness', 'faerie fire'],
#  ['sacred flame',
#   'thaumaturgy',
#   'command',
#   'guiding bolt',
#   'shield of faith',
#   'hold person',
#   'silence',
#   'spiritual weapon',
#   'animate dead',
#   'dispel magic',
#   'stone shape',
#   'guardian of faith',
#   'contagion',
#   'insect plague',
#   'harm'],
#  ['dancing lights',
#   'fire bolt',
#   'light',
#   'mage hand',
#   'prestidigitation',
#   'mage armor',
#   'magic missile',
#   'shield',
#   'silent image',
#   'arcane lock',
#   'cloud of daggers',
#   'darkvision',
#   'knock',
#   'counterspell',
#   'dispel magic',
#   'fireball',
#   'confusion',
#   'hallucinatory terrain',
#   'polymorph',
#   "Bigby's hand",
#   'geas',
#   'wall of force',
#   'chain lightning',
#   'globe of invulnerability',
#   'programmed illusion',
#   'finger of death',
#   'symbol',
#   'teleport',
#   'maze',
#   'mind blank',
#   'meteor swarm',
#   'wish',
#   'disguise self',
#   'invisibility',
#   'fly',
#   'lightning bolt'],
#  ['dancing lights',
#   'mage hand',
#   "Melf's acid arrow",
#   'darkness',
#   'faerie fire',
#   'shield'],
#  ['guidance',
#   'mending',
#   'resistance',
#   'thaumaturgy',
#   'bane',
#   'command',
#   'inflict wounds',
#   'ray of sickness',
#   'blindness/deafness',
#   'ray of enfeeblement',
#   'spiritual weapon',
#   'animate dead',
#   'bestow curse',
#   'dispel magic',
#   'spirit guardians',
#   'blight',
#   'death ward',
#   'divination',
#   'antilife shell',
#   'destructive wave'],
#  ['dancing lights',
#   'mage hand',
#   'prestidigitation',
#   'ray of frost',
#   'shocking grasp',
#   'expeditious retreat',
#   'fog cloud',
#   'magic missile',
#   'shield',
#   'darkness',
#   'knock',
#   'see invisibility',
#   'spider climb',
#   'animate dead',
#   'counterspell',
#   'lightning bolt',
#   'greater invisibility',
#   'polymorph',
#   'animate objects',
#   'wall of force',
#   'create undead',
#   'flesh to stone',
#   'finger of death'],
#  ['mage hand',
#   'magic missile',
#   'shield',
#   'blur',
#   'flaming sphere',
#   'lightning bolt'],
#  ['fire bolt',
#   'mage hand',
#   'prestidigitation',
#   'detect magic',
#   'magic missile',
#   'shield',
#   'blur',
#   'detect thoughts',
#   'misty step',
#   'shatter',
#   'counterspell',
#   'dispel magic',
#   'fireball',
#   'haste',
#   'blight',
#   'greater invisibility',
#   'animate objects',
#   "Bigby's hand",
#   'scrying',
#   'chain lightning',
#   'globe of invulnerability',
#   'finger of death',
#   'forcecage',
#   'incendiary cloud',
#   'power word stun',
#   'power word kill']]
